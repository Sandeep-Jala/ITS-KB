# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
import jaydebeapi as dbdriver
import credential  # Ensure this contains your credentials like db_user, db_password
import pandas as pd
from gspread_dataframe import set_with_dataframe, get_as_dataframe
from bs4 import BeautifulSoup
import re
from socket import gethostname
import os
from googleapiclient.errors import HttpError
import json
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
import pandas as pd

# %%
SCOPES = ['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/documents', 'https://www.googleapis.com/auth/spreadsheets']

# Authenticate to Google API
def authenticate():
    credentials = service_account.Credentials.from_service_account_file(
        'service_account.json', scopes=SCOPES)
    return credentials

# %%
def update_google_doc(doc_id, content):
    try:
        creds = authenticate()
        doc_service = build('docs', 'v1', credentials=creds)
        
        doc = doc_service.documents().get(documentId=doc_id).execute()
        end_index = doc.get('body').get('content')[-1].get('endIndex')
        requests = [
            {
                'insertText': {
                    'location': {'index':  end_index-1 },
                    'text': content
                }
            }
        ]
        
        doc_service.documents().batchUpdate(
            documentId=doc_id,
            body={'requests': requests}
        ).execute()
        
        return True
    except HttpError as error:
        print(f"An error occurred while updating Google Doc: {error}")
        return False

# %%
def load_tracking_dict_from_spreadsheet(spreadsheet_title, folder_id=None):
    try:
        # Authenticate and connect to Google Sheets
        creds = authenticate()
        gc = gspread.authorize(creds)

        # Search for the spreadsheet in the specified folder
        if folder_id:
            drive_service = build('drive', 'v3', credentials=creds)
            query = f"'{folder_id}' in parents and name = '{spreadsheet_title}' and mimeType = 'application/vnd.google-apps.spreadsheet'"
            results = drive_service.files().list(
    q=query,
    spaces='drive',
    fields='files(id, name)',
    supportsAllDrives=True,
    includeItemsFromAllDrives=True
).execute()
            files = results.get('files', [])

            if not files:
                print(f"Spreadsheet '{spreadsheet_title}' not found in folder ID {folder_id}.")
                return {}

            # Get the file ID of the spreadsheet
            file_id = files[0]['id']
            spreadsheet = gc.open_by_key(file_id)
        else:
            # Open the spreadsheet by its title (assumes it's in "My Drive")
            spreadsheet = gc.open(spreadsheet_title)

        # Load data from the spreadsheet into a DataFrame
        sheet = spreadsheet.sheet1
        df = get_as_dataframe(sheet, dtype=str, na_values=[]).dropna(how='all')  # Clean empty rows
        df.set_index('Article ID', inplace=True)

        # Convert the DataFrame to a dictionary
        tracking_dict = df.to_dict(orient='index')
        return tracking_dict
    except Exception as e:
        print(f"An error occurred while loading the tracking dictionary: {e}")
        return {}

# %%
def clean_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup.get_text(separator=' ', strip=True)

# %%
df = pd.read_csv('subset_sampled_clusters.csv')
spreadsheet_folder_id = '0ADjQe-gJ6HwnUk9PVA'

# %%
df.shape
# Out:
# (11766, 7)

# %%
group_sizes = df.groupby(['Knowledge Base Article', 'Knowledge Base Article Links']).size()

# Step 2: Get only groups with size > 50
large_groups = group_sizes[group_sizes > 100].index
print(f"Number of groups with size > 100: {len(large_groups)}")
large_groups_df = df[df.set_index(['Knowledge Base Article', 'Knowledge Base Article Links']).index.isin(large_groups)]
large_groups_df
# Out:
# Number of groups with size > 100: 2
#        Ticket ID               Title  \
# 30       7162364  TeamDynamix Access
# 57       7754376  TeamDynamix Access
# 75       8031925  TeamDynamix Access
# 80       7048603  TeamDynamix Groups
# 88       6383577  TeamDynamix Access
# ...          ...                 ...
# 11623    7203730  TeamDynamix Access
# 11650    7192767  TeamDynamix Groups
# 11660    8105078  TeamDynamix Access
# 11684    6891766  TeamDynamix Access
# 11730    7093495  TeamDynamix Access
#
#                                              Description  \
# 30      New employee. Need access to Teamdynamix tickets
# 57                         CoE Accessibility technicians
# 75     These students are working on a project and wi...
# 80     This is a TeamDynamix Groups Request. Please r...
# 88     Student worker and forgot to give KB Access.&n...
# ...                                                  ...
# 11623  Hi,<br><br>Please add Kristen McCray (mccrayk)...
# 11650  This is a TeamDynamix Groups Request. Please r...
# 11660  Please provide access so person can submit SOD...
# 11684              <h1>Onboarding Request for eivan</h1>
# 11730  Student staff selected to investigate inventor...
#
#                                   Knowledge Base Article  KB Article ID  \
# 30     TeamDynamix Admins: Requesting Access, Approva...           3189
# 57     TeamDynamix Admins: Requesting Access, Approva...           3189
# 75     TeamDynamix Admins: Requesting Access, Approva...           3189
# 80               Request a TeamDynamix Responsible Group           3131
# 88     TeamDynamix Admins: Requesting Access, Approva...           3189
# ...                                                  ...            ...
# 11623  TeamDynamix Admins: Requesting Access, Approva...           3189
# 11650            Request a TeamDynamix Responsible Group           3131
# 11660  TeamDynamix Admins: Requesting Access, Approva...           3189
# 11684  TeamDynamix Admins: Requesting Access, Approva...           3189
# 11730  TeamDynamix Admins: Requesting Access, Approva...           3189
#
#                             Knowledge Base Article Links  Cluster
# 30     https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 57     https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 75     https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 80     https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 88     https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# ...                                                  ...      ...
# 11623  https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 11650  https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 11660  https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 11684  https://teamdynamix.umich.edu/TDClient/30/Port...       -1
# 11730  https://teamdynamix.umich.edu/TDClient/30/Port...       -1
#
# [489 rows x 7 columns]

# %%
tracking_dict_for_public = load_tracking_dict_from_spreadsheet("Public Tracking", spreadsheet_folder_id)
tracking_dict_for_um_login = load_tracking_dict_from_spreadsheet("UM-Login Tracking", spreadsheet_folder_id)
tracking_dict_for_support_staff = load_tracking_dict_from_spreadsheet("Support Staff Tracking", spreadsheet_folder_id)

# %%
# size of the tracking dictionaries
tracking_dict_for_um_login_size = len(tracking_dict_for_um_login)
tracking_dict_for_public_size = len(tracking_dict_for_public)
tracking_dict_for_support_staff_size = len(tracking_dict_for_support_staff)
print(f"Size of tracking dictionary for UM-Login: {tracking_dict_for_um_login_size}")
print(f"Size of tracking dictionary for Public: {tracking_dict_for_public_size}")
print(f"Size of tracking dictionary for Support Staff: {tracking_dict_for_support_staff_size}")
# Out:
# Size of tracking dictionary for UM-Login: 246
# Size of tracking dictionary for Public: 1746
# Size of tracking dictionary for Support Staff: 3086

# %%
tracking_sources = [tracking_dict_for_public, tracking_dict_for_um_login, tracking_dict_for_support_staff]

# %%
for (article, link), group in df.groupby(['Knowledge Base Article', 'Knowledge Base Article Links']):
    match = re.search(r'ID=([\w-]+)', link)
    if not match:
        print(f"Skipping article without valid ID: {article} | Link: {link}")
        continue

    article_id = match.group(1)

    doc_id = None
    for tracking_dict in tracking_sources:
        if article_id in tracking_dict:
            doc_id = tracking_dict[article_id]['doc_id']
            print(f"Found article ID '{article_id}' in tracking dict. Using Google Doc ID: {doc_id}")
            break

    if not doc_id:
        #print(f"Article ID '{article_id}' not found in any tracking dict. Skipping: {article}")
        continue

    # Compose content to append
    content_lines = [f"\nExample Queries that use this article:\n"]
    for _, row in group.iterrows():
        content_lines.append(f"- Title: {row['Title']}\n")
        desc_raw = row['Description']
        Clean_Description = clean_html(desc_raw) if pd.notna(desc_raw) else "  "

        content_lines.append(f"  Description: {Clean_Description}\n")
    content = ''.join(content_lines)
    try:
        update_google_doc(doc_id, content)
        print(f"Successfully updated Google Doc (ID: {doc_id}) for article '{article}'")
    except Exception as e:
        print(f"Failed to update Google Doc (ID: {doc_id}) for article '{article}': {e}")
# Out:
# Found article ID '8621' in tracking dict. Using Google Doc ID: 1xjr9von22hIMunIzHSIouLo7NAvvj7ikIAyDkjnlSG8
# Successfully updated Google Doc (ID: 1xjr9von22hIMunIzHSIouLo7NAvvj7ikIAyDkjnlSG8) for article '"400 Bad Request" Error When Adding Members To MCommunity Group'
# Found article ID '6468' in tracking dict. Using Google Doc ID: 1J58PrFxy7vRfD7x6bRQyZEoZBjJVxY-TmNldAnSsyN4
# Successfully updated Google Doc (ID: 1J58PrFxy7vRfD7x6bRQyZEoZBjJVxY-TmNldAnSsyN4) for article '"Account Lockout!" - Account Recovery Locked Due to Repeated Reset Attempts'
# Found article ID '7030' in tracking dict. Using Google Doc ID: 1FegVL7P7ukcwQ1sZH-PvllONclgenR6mBWozWcgiwI4
# Successfully updated Google Doc (ID: 1FegVL7P7ukcwQ1sZH-PvllONclgenR6mBWozWcgiwI4) for article '"Accounts for People Who Leave U-M" Documentation'
# Found article ID '9489' in tracking dict. Using Google Doc ID: 1XOta4z0o8BF9g-J7J_zZ0eu1lJlEv4AVEwcVJh0LOWI
# Successfully updated Google Doc (ID: 1XOta4z0o8BF9g-J7J_zZ0eu1lJlEv4AVEwcVJh0LOWI) for article '"Create a New Shared Drive" Button Does Not Work in Google'
# Found article ID '11170' in tracking dict. Using Google Doc ID: 1KvvbGTGJToB9XYjzW5WM-QtV--MBZfh4whVZR8dfX4g
# Successfully updated Google Doc (ID: 1KvvbGTGJToB9XYjzW5WM-QtV--MBZfh4whVZR8dfX4g) for article '"Data Being Updated Does Not Exist" Error When Saving or Submitting an ePro Requisition'
# Found article ID '3756' in tracking dict. Using Google Doc ID: 1OvaGM2q0ajN4wQ1RSlghuW28f2BM9Sb3EsUzUO9xnCI
# Successfully updated Google Doc (ID: 1OvaGM2q0ajN4wQ1RSlghuW28f2BM9Sb3EsUzUO9xnCI) for article '"Error Loading Page" Message Trying to Access M-Pathways/PeopleSoft Systems'
# Found article ID '10913' in tracking dict. Using Google Doc ID: 1L8hn_D4ogF3P1epV9SMvS0wm0QByNvo2RP-WLQO6jjc
# Successfully updated Google Doc (ID: 1L8hn_D4ogF3P1epV9SMvS0wm0QByNvo2RP-WLQO6jjc) for article '"Release of Information Prevented" Error'
# Found article ID '1859' in tracking dict. Using Google Doc ID: 18hK_xO6giW13z2fjjiO3DClaX-AmBAxjaNgGOCOLadw
# Successfully updated Google Doc (ID: 18hK_xO6giW13z2fjjiO3DClaX-AmBAxjaNgGOCOLadw) for article '"This Connection is Not Private" Error on UMICH Sites'
# Found article ID '5940' in tracking dict. Using Google Doc ID: 14mc2R45dZgJrK0n4rePljIhwRgS6Oyp1dalNHDpmY2s
# Successfully updated Google Doc (ID: 14mc2R45dZgJrK0n4rePljIhwRgS6Oyp1dalNHDpmY2s) for article '"This Identity is Impounded" Error In IAM Admin Tools'
# Found article ID '1398' in tracking dict. Using Google Doc ID: 1lda7n528RHtrCDc9lfKeSWkApyj9CTf5frNTNLXlBKQ
# Successfully updated Google Doc (ID: 1lda7n528RHtrCDc9lfKeSWkApyj9CTf5frNTNLXlBKQ) for article '"This Site Can't be Reached" When Visiting Employee Self-Service Page'
# Found article ID '9652' in tracking dict. Using Google Doc ID: 1DXcXRD0U9Idc8qzopU7POQ6VcBHz7SGkNWjszwwp784
# Successfully updated Google Doc (ID: 1DXcXRD0U9Idc8qzopU7POQ6VcBHz7SGkNWjszwwp784) for article '"This site can't be reached" When Viewing Document Attached to Voucher or JE'
# Found article ID '4301' in tracking dict. Using Google Doc ID: 1ZjBdMX_I7lLknno5rmXoC8q2rpIGWhcUFoOCQ8Vyo14
# Successfully updated Google Doc (ID: 1ZjBdMX_I7lLknno5rmXoC8q2rpIGWhcUFoOCQ8Vyo14) for article '"This site cannot be reached" Error When Accessing U-M Resources From Off Campus (Non-VPN)'
# Found article ID '237' in tracking dict. Using Google Doc ID: 1Zv8OtU-VnZsfv_nSsYMmiCkAvAcLLuW0Tr4Wecd2Tqk
# Successfully updated Google Doc (ID: 1Zv8OtU-VnZsfv_nSsYMmiCkAvAcLLuW0Tr4Wecd2Tqk) for article '"Unable to connect to the RenServer." Error When Running MPathways Report'
# Found article ID '10782' in tracking dict. Using Google Doc ID: 1ulXDIoeuDqpd-kWA0mdw6Xx7WvUNY6cjBy3lHSPXrQU
# Successfully updated Google Doc (ID: 1ulXDIoeuDqpd-kWA0mdw6Xx7WvUNY6cjBy3lHSPXrQU) for article '"Unsupported Request" Error on U-M Sites'
# Found article ID '5957' in tracking dict. Using Google Doc ID: 1fIt8MOC5cR15nsBAOen0MD9zdifLJPWbcMSpielcCi0
# Successfully updated Google Doc (ID: 1fIt8MOC5cR15nsBAOen0MD9zdifLJPWbcMSpielcCi0) for article '"Windows License Will Expire Soon" Error'
# Found article ID '7768' in tracking dict. Using Google Doc ID: 1dIhMiXprRj5WuHcz_esf0Vde07Zo-wFPUPbw8VuDNfo
# Successfully updated Google Doc (ID: 1dIhMiXprRj5WuHcz_esf0Vde07Zo-wFPUPbw8VuDNfo) for article '"You Do Not Have Access to Google Developers" Error'
# Found article ID '6464' in tracking dict. Using Google Doc ID: 1ILlYWR46zKJ9D32b2QqOALxscwgh4jlwLsM6xe6DjkU
# Successfully updated Google Doc (ID: 1ILlYWR46zKJ9D32b2QqOALxscwgh4jlwLsM6xe6DjkU) for article '2-Tier Password Resets'
# Found article ID '929' in tracking dict. Using Google Doc ID: 1jzn41FA_OjXKjtJAMe_XwdTO2rYv4N-B3y1kMJJj85Y
# Successfully updated Google Doc (ID: 1jzn41FA_OjXKjtJAMe_XwdTO2rYv4N-B3y1kMJJj85Y) for article '2.4GHz Frequency Removed from Ann Arbor MWireless Network'
# Found article ID '5785' in tracking dict. Using Google Doc ID: 1E8vSsa12eAMAP9vW0aeIr8DglFLNUqP7J_evtMtoFXE
# Successfully updated Google Doc (ID: 1E8vSsa12eAMAP9vW0aeIr8DglFLNUqP7J_evtMtoFXE) for article '3D Printer in Munger Graduate Residence'
# Found article ID '4547' in tracking dict. Using Google Doc ID: 1JEQ9WZkC1R1snPxBzcvC4qt8KEmfPQ4FY-UGnM2R0UA
# Successfully updated Google Doc (ID: 1JEQ9WZkC1R1snPxBzcvC4qt8KEmfPQ4FY-UGnM2R0UA) for article '400 Bad Request Error'
# Found article ID '7224' in tracking dict. Using Google Doc ID: 1uWqNoGA80e2VRyO4NtbwWQrVgATbOWU9c43ytLFC_To
# Successfully updated Google Doc (ID: 1uWqNoGA80e2VRyO4NtbwWQrVgATbOWU9c43ytLFC_To) for article '403 Forbidden Error'
# Found article ID '3799' in tracking dict. Using Google Doc ID: 1Mpr17EomTFO9RhvxI-ADrYpCBxP-tIxwpisppsJcOdM
# Successfully updated Google Doc (ID: 1Mpr17EomTFO9RhvxI-ADrYpCBxP-tIxwpisppsJcOdM) for article '504 Gateway Timeout Error on New Wolverine Access'
# Found article ID '1043' in tracking dict. Using Google Doc ID: 1Z7pnzOpxOXuH3hb-5uWAlPh9-LfAqfZJwYWRqHfehP8
# Successfully updated Google Doc (ID: 1Z7pnzOpxOXuH3hb-5uWAlPh9-LfAqfZJwYWRqHfehP8) for article 'ABLE Bindery Software - Application Use and  Troubleshooting'
# Found article ID '11414' in tracking dict. Using Google Doc ID: 19cjPjPE8TAbf3hoxBeUlO96d5fHzvpkYhzEXvFOsU8Y
# Successfully updated Google Doc (ID: 19cjPjPE8TAbf3hoxBeUlO96d5fHzvpkYhzEXvFOsU8Y) for article 'AFS Personal/Group Websites Requires Weblogin (Implementing HTTPS-Only Service on UMICH Personal/Group Websites)'
# Found article ID '11065' in tracking dict. Using Google Doc ID: 1T9tMZTRUY39_g_17LPyoj8prXJ-frYgSFmBP6aRkiIE
# Successfully updated Google Doc (ID: 1T9tMZTRUY39_g_17LPyoj8prXJ-frYgSFmBP6aRkiIE) for article 'AFS Retirement of Alumni/Retiree AFS Directories and Websites'
# Found article ID '12155' in tracking dict. Using Google Doc ID: 16PLMQkxxxQIrkdqF0xUGx7hu5IscBHmSWyyplr27_Dc
# Successfully updated Google Doc (ID: 16PLMQkxxxQIrkdqF0xUGx7hu5IscBHmSWyyplr27_Dc) for article 'AI-Driven Ticket Triage'
# Found article ID '3185' in tracking dict. Using Google Doc ID: 1yXDHcNvx07XHhwCV-_0bdNhEybCnE0U_JPwE2H64qwY
# Successfully updated Google Doc (ID: 1yXDHcNvx07XHhwCV-_0bdNhEybCnE0U_JPwE2H64qwY) for article 'AT&T Centrex Line Triage and Escalation Steps'
# Found article ID '5995' in tracking dict. Using Google Doc ID: 1_3ebc-zGojvCrzfQ_QLZGLON9XnTyGpPzgwXllgnYKU
# Successfully updated Google Doc (ID: 1_3ebc-zGojvCrzfQ_QLZGLON9XnTyGpPzgwXllgnYKU) for article 'ATSG (formerly Optanix: Support for Hospital (Michigan Medicine) Telephone Services'
# Found article ID '9356' in tracking dict. Using Google Doc ID: 1vDYqqGsmd7e67MMWOVbCFcwI7TffdHmtcEC0tu4sy2E
# Successfully updated Google Doc (ID: 1vDYqqGsmd7e67MMWOVbCFcwI7TffdHmtcEC0tu4sy2E) for article 'About the Online Purchasing System (OPS)'
# Found article ID '842' in tracking dict. Using Google Doc ID: 1uMOVqh0Eveq9qN_gnI5zF7RP0_eUekzlj9TV7G52PTA
# Successfully updated Google Doc (ID: 1uMOVqh0Eveq9qN_gnI5zF7RP0_eUekzlj9TV7G52PTA) for article 'Access & Compliance Agreement'
# Found article ID '788' in tracking dict. Using Google Doc ID: 18EMYerRXgtQazHw3sYBmEsAumILqATcZTOPoF1IsFG8
# Successfully updated Google Doc (ID: 18EMYerRXgtQazHw3sYBmEsAumILqATcZTOPoF1IsFG8) for article 'Access IFS/AFS Files to Determine Ownership or Contents'
# Found article ID '2880' in tracking dict. Using Google Doc ID: 1xV3eBVwWG0xx8dyuxVtsBpoz_zjQ_k6hYaf3Sma6Cr0
# Successfully updated Google Doc (ID: 1xV3eBVwWG0xx8dyuxVtsBpoz_zjQ_k6hYaf3Sma6Cr0) for article 'Access In-State Tuition Application with Uniqname for Flint and Dearborn Students'
# Found article ID '2847' in tracking dict. Using Google Doc ID: 1QvBrtZPSW13D_ZqGDQKgQoBpGCDobfn0OP2y2-IrWrU
# Successfully updated Google Doc (ID: 1QvBrtZPSW13D_ZqGDQKgQoBpGCDobfn0OP2y2-IrWrU) for article 'Access My LINC on Mobile Devices'
# Found article ID '1254' in tracking dict. Using Google Doc ID: 1s9pCAMA4GjpX3TZ8NMXKYfrBnTpIK0OzvjCyXJmTuBs
# Successfully updated Google Doc (ID: 1s9pCAMA4GjpX3TZ8NMXKYfrBnTpIK0OzvjCyXJmTuBs) for article 'Access U-M Google Mail (Gmail) on Mobile Phone or Tablet'
# Found article ID '244' in tracking dict. Using Google Doc ID: 1882ti0Tjzv8CIq4wMEZTgF_I73Lo47lAHz_TURwLTsM
# Successfully updated Google Doc (ID: 1882ti0Tjzv8CIq4wMEZTgF_I73Lo47lAHz_TURwLTsM) for article 'Access Unit-Maintained Folder in BusinessObjects'
# Found article ID '3577' in tracking dict. Using Google Doc ID: 1M5JXRK5dNS-Dv7V13neEwt9sE8kRd4WCV43arztvsag
# Successfully updated Google Doc (ID: 1M5JXRK5dNS-Dv7V13neEwt9sE8kRd4WCV43arztvsag) for article 'Access University Business Tasks in Wolverine Access'
# Found article ID '3957' in tracking dict. Using Google Doc ID: 1dIFLluAi4PMwSeoO4iotehYNo-BbVTujiPL8P33G0yU
# Successfully updated Google Doc (ID: 1dIFLluAi4PMwSeoO4iotehYNo-BbVTujiPL8P33G0yU) for article 'Access a Course in My LINC'
# Found article ID '229' in tracking dict. Using Google Doc ID: 1_RB6wcVdEZ3MxIneXWAZMQ12SWRJIkufHaHoR3k_4oI
# Successfully updated Google Doc (ID: 1_RB6wcVdEZ3MxIneXWAZMQ12SWRJIkufHaHoR3k_4oI) for article 'Access a Shared Drive from a Personal Computer'
# Found article ID '191' in tracking dict. Using Google Doc ID: 131Q1f7uDvcP3tga_w4x9PyeSBs2Y_dPcyNno_yeVknM
# Successfully updated Google Doc (ID: 131Q1f7uDvcP3tga_w4x9PyeSBs2Y_dPcyNno_yeVknM) for article 'Access and Complete the Spanish Placement Exam in Canvas'
# Found article ID '122' in tracking dict. Using Google Doc ID: 1EMsVWPmMjwQJp3U2ukVyBDh1uRLWyWNMBgCaidH7cV0
# Successfully updated Google Doc (ID: 1EMsVWPmMjwQJp3U2ukVyBDh1uRLWyWNMBgCaidH7cV0) for article 'Access to Approve Time for Supervisors'
# Found article ID '1215' in tracking dict. Using Google Doc ID: 10Kl_pM4EMZNqcwxd8LlIWo1pRf7-M-SSTf5BS_faHE0
# Successfully updated Google Doc (ID: 10Kl_pM4EMZNqcwxd8LlIWo1pRf7-M-SSTf5BS_faHE0) for article 'Access to Employee Self-Service for Former or Terminated Employee'
# Found article ID '1259' in tracking dict. Using Google Doc ID: 1SIEPIp_7j26uxXNssQ0rusETSbyr936rOaS17Naz8IM
# Successfully updated Google Doc (ID: 1SIEPIp_7j26uxXNssQ0rusETSbyr936rOaS17Naz8IM) for article 'Access to My LINC for Sponsored Affiliates, Incoming Students and New Hires'
# Found article ID '6514' in tracking dict. Using Google Doc ID: 1Ibf9xmjWcMBwCjjEWqF3foNDSUWbVWhTjZyhFbthee8
# Successfully updated Google Doc (ID: 1Ibf9xmjWcMBwCjjEWqF3foNDSUWbVWhTjZyhFbthee8) for article 'Access to SAS Installation Files'
# Found article ID '12367' in tracking dict. Using Google Doc ID: 1NdivtJ7VwrmBqV5B1wd2awGs6PqgF8dh_K1p_8XIJpg
# Successfully updated Google Doc (ID: 1NdivtJ7VwrmBqV5B1wd2awGs6PqgF8dh_K1p_8XIJpg) for article 'Access to the Service Request System (SRS)'
# Found article ID '8267' in tracking dict. Using Google Doc ID: 1fpZUdUevHoy77IzaAeFZE9N4UvI3BuWxCm6KbglJVYk
# Successfully updated Google Doc (ID: 1fpZUdUevHoy77IzaAeFZE9N4UvI3BuWxCm6KbglJVYk) for article 'Accessibility Accommodation Requests and Accessibility Issue Reports'
# Found article ID '8268' in tracking dict. Using Google Doc ID: 19mRP0pdW2nsN5HZKhn8bzM0d_V_-hfs479GuVWANkFo
# Successfully updated Google Doc (ID: 19mRP0pdW2nsN5HZKhn8bzM0d_V_-hfs479GuVWANkFo) for article 'Accessibility Request Using a Product or Improving Information Technology'
# Found article ID '10739' in tracking dict. Using Google Doc ID: 1OwRez0FW07f2RxlFrEHc_6ZHOmjhP15LnwEfijstOLE
# Successfully updated Google Doc (ID: 1OwRez0FW07f2RxlFrEHc_6ZHOmjhP15LnwEfijstOLE) for article 'Accessibility Scanning Support (Deque axe Monitor)'
# Found article ID '9660' in tracking dict. Using Google Doc ID: 1_hRrqn1jLQ578hDThULJ6Zzjl9gmWCF1YCArOa542Q0
# Successfully updated Google Doc (ID: 1_hRrqn1jLQ578hDThULJ6Zzjl9gmWCF1YCArOa542Q0) for article 'Accessing 1098-T Tax Form'
# Found article ID '397' in tracking dict. Using Google Doc ID: 141fLFThlUke7MF0YEjf2ydY3oDtPeLb__RcrVCQaPQ0
# Successfully updated Google Doc (ID: 141fLFThlUke7MF0YEjf2ydY3oDtPeLb__RcrVCQaPQ0) for article 'Accessing Benefits or Direct Deposit for a Sponsored Affiliate'
# Found article ID '11543' in tracking dict. Using Google Doc ID: 1H6u-IMZ0voyG5qHAf5HsQXyVB-G4HThFnXmkXNLTFZs
# Successfully updated Google Doc (ID: 1H6u-IMZ0voyG5qHAf5HsQXyVB-G4HThFnXmkXNLTFZs) for article 'Accessing Form 1095 in Wolverine Access'
# Found article ID '7977' in tracking dict. Using Google Doc ID: 1QVnpMPjKcdtb_jwn-nnm6gvptfVUSFCzJ5hIKZXxLMM
# Successfully updated Google Doc (ID: 1QVnpMPjKcdtb_jwn-nnm6gvptfVUSFCzJ5hIKZXxLMM) for article 'Accessing Michigan Medicine Microsoft Teams from a MiWorkspace Device'
# Found article ID '256' in tracking dict. Using Google Doc ID: 1GpPfo3r7qfrTpIZ1_H63UPlM4fFqVuL1_zJ5wU14-l4
# Successfully updated Google Doc (ID: 1GpPfo3r7qfrTpIZ1_H63UPlM4fFqVuL1_zJ5wU14-l4) for article 'Accessing Michigan Online and Other Online Courses'
# Found article ID '336' in tracking dict. Using Google Doc ID: 1KTZnowtvZB_h7uzsn-lOckwIhOzEHtEL7Z6aSdsyZtE
# Successfully updated Google Doc (ID: 1KTZnowtvZB_h7uzsn-lOckwIhOzEHtEL7Z6aSdsyZtE) for article 'Accessing U-M Library Resources'
# Found article ID '4549' in tracking dict. Using Google Doc ID: 1bESMbEw5NOD2FwlOzvRAs9rZ-E13P4SU-yUS05xREPk
# Successfully updated Google Doc (ID: 1bESMbEw5NOD2FwlOzvRAs9rZ-E13P4SU-yUS05xREPk) for article 'Accessing UpToDate as a Student'
# Found article ID '9454' in tracking dict. Using Google Doc ID: 1SIFR2oVSMAij47Eqz04I4Z0IUIezbi1_Q9XKaln0lCQ
# Successfully updated Google Doc (ID: 1SIFR2oVSMAij47Eqz04I4Z0IUIezbi1_Q9XKaln0lCQ) for article 'Accessing the Adobe Acrobat Web Interface'
# Found article ID '7147' in tracking dict. Using Google Doc ID: 1t_nNmbbJejDDmZed6qTfxnS6GS4XQ75ROG35yhH_idI
# Successfully updated Google Doc (ID: 1t_nNmbbJejDDmZed6qTfxnS6GS4XQ75ROG35yhH_idI) for article 'Account Access for Spouse, Caregiver, Parent, or Other Next of Kin'
# Found article ID '5831' in tracking dict. Using Google Doc ID: 1oL4ksXfzf40kMr1hn5yipfocP8HOL0jqMM7XBZaaP7c
# Successfully updated Google Doc (ID: 1oL4ksXfzf40kMr1hn5yipfocP8HOL0jqMM7XBZaaP7c) for article 'Activate Uniqname for Transcript or Other U-M Service'
# Found article ID '1282' in tracking dict. Using Google Doc ID: 1Umyh0ioArrlmT9ZAso9s3XdCqK6cgpce0o5SIInwqk4
# Successfully updated Google Doc (ID: 1Umyh0ioArrlmT9ZAso9s3XdCqK6cgpce0o5SIInwqk4) for article 'Activate a Port'
# Found article ID '9509' in tracking dict. Using Google Doc ID: 1FKmcBrX7ZvR0duibqQ79SynZlze92bJ1WxyarQclkN0
# Successfully updated Google Doc (ID: 1FKmcBrX7ZvR0duibqQ79SynZlze92bJ1WxyarQclkN0) for article 'Activate a Port on SwitchConf (NetDash) - For Neighborhood IT in MiWorkspace'
# Found article ID '768' in tracking dict. Using Google Doc ID: 1LiTcdAssbmQmvuYqcnOdQmxUvFmht3-shHbQonwQ0sY
# Successfully updated Google Doc (ID: 1LiTcdAssbmQmvuYqcnOdQmxUvFmht3-shHbQonwQ0sY) for article 'Active Directory (AD) Account Disabled'
# Found article ID '7000' in tracking dict. Using Google Doc ID: 1c0fPFEfPaR1GB1Va45QmrkoUzbCeLRLTTZ2EjQPAm5c
# Successfully updated Google Doc (ID: 1c0fPFEfPaR1GB1Va45QmrkoUzbCeLRLTTZ2EjQPAm5c) for article 'Active Directory (AD) Account Locked'
# Found article ID '292' in tracking dict. Using Google Doc ID: 15ZbmOFN1hYE68Evw1Ph9FQS8A00LjJjl-dECVg9Ftkk
# Successfully updated Google Doc (ID: 15ZbmOFN1hYE68Evw1Ph9FQS8A00LjJjl-dECVg9Ftkk) for article 'Active Learning Platform (ALP) Support Referrals (Echo360) (Support Staff)'
# Found article ID '4373' in tracking dict. Using Google Doc ID: 1sWV20Yab7CSKvi1qKa1Ow3NDcZ_bbHfXpyLmgTAGHaI
# Successfully updated Google Doc (ID: 1sWV20Yab7CSKvi1qKa1Ow3NDcZ_bbHfXpyLmgTAGHaI) for article 'Active/Prospective Student Fix Incorrect Personal Data in CSPROD'
# Found article ID '3981' in tracking dict. Using Google Doc ID: 1gOya6AnFGbIb2-NJ3o-fJ0o3fA3s8lIai8Fj0nGCVyk
# Successfully updated Google Doc (ID: 1gOya6AnFGbIb2-NJ3o-fJ0o3fA3s8lIai8Fj0nGCVyk) for article 'Add Members and Owners to an MCommunity Group'
# Found article ID '5617' in tracking dict. Using Google Doc ID: 1AqqvLOHH3pT7E0f5-6syyIQXxhCIgUszXSX9uG6PMDg
# Successfully updated Google Doc (ID: 1AqqvLOHH3pT7E0f5-6syyIQXxhCIgUszXSX9uG6PMDg) for article 'Add People After a Canvas Course Has Ended (Support Staff)'
# Found article ID '8612' in tracking dict. Using Google Doc ID: 12TP9KGFxnnHPHPxMF2i19qH7itLJ-aTykkTOHIh6E3s
# Successfully updated Google Doc (ID: 12TP9KGFxnnHPHPxMF2i19qH7itLJ-aTykkTOHIh6E3s) for article 'Add Permitted Senders and Disallowed Message Recipient to an MCommunity Group'
# Found article ID '11012' in tracking dict. Using Google Doc ID: 1Z99ormYZEwE47Mk5Cd3PrnGLHhjYxOyeCOlH2-w7v9I
# Successfully updated Google Doc (ID: 1Z99ormYZEwE47Mk5Cd3PrnGLHhjYxOyeCOlH2-w7v9I) for article 'Add Person to a TeamDynamix Ticket'
# Found article ID '80' in tracking dict. Using Google Doc ID: 1x90kYccqRcPDT5KUglR_VpAAWfSL4p0Z0YpviypImPM
# Successfully updated Google Doc (ID: 1x90kYccqRcPDT5KUglR_VpAAWfSL4p0Z0YpviypImPM) for article 'Add Someone as Owner of MCommunity Group(s) -- 4HELP Service Center Directory Administration'
# Found article ID '9022' in tracking dict. Using Google Doc ID: 1dDHzV7zu9mTYcIkAsXlJfJVbca691JNUWvVdeArpJU4
# Successfully updated Google Doc (ID: 1dDHzV7zu9mTYcIkAsXlJfJVbca691JNUWvVdeArpJU4) for article 'Add Sub-Groups to an MCommunity Group'
# Found article ID '8704' in tracking dict. Using Google Doc ID: 1Ehkd_I3sPsDn5_ky9W-Bc5DBv2F1G7hHYRtpxQMJHz8
# Successfully updated Google Doc (ID: 1Ehkd_I3sPsDn5_ky9W-Bc5DBv2F1G7hHYRtpxQMJHz8) for article 'Add U-M Academic Calendar to Google Calendar'
# Found article ID '6195' in tracking dict. Using Google Doc ID: 1fjMa81qBds6u8JZDbBr8uMOAUSQmB4OKDZ010BEFPq0
# Successfully updated Google Doc (ID: 1fjMa81qBds6u8JZDbBr8uMOAUSQmB4OKDZ010BEFPq0) for article 'Add a Batch List of Names to My LINC'
# Found article ID '3621' in tracking dict. Using Google Doc ID: 1hiVzG1ihSsmpIHwGc92ajY_ETnY1i3LE4FvF-NMB9nM
# Successfully updated Google Doc (ID: 1hiVzG1ihSsmpIHwGc92ajY_ETnY1i3LE4FvF-NMB9nM) for article 'Add a New Device to Duo After an Initial Device Has Been Enrolled'
# Found article ID '4517' in tracking dict. Using Google Doc ID: 1Q_feFDWpQ1xoTKeECEnMZoKj_a6X6Q3IAHNpluYlfww
# Successfully updated Google Doc (ID: 1Q_feFDWpQ1xoTKeECEnMZoKj_a6X6Q3IAHNpluYlfww) for article 'Add a New Ship To Location Code for ePro Requisition'
# Found article ID '6348' in tracking dict. Using Google Doc ID: 1-wsMu-_vGeTN43K1OJkq0P_Ziqq-uPGKgGuzctNydms
# Successfully updated Google Doc (ID: 1-wsMu-_vGeTN43K1OJkq0P_Ziqq-uPGKgGuzctNydms) for article 'Add a Redirect (Custom) URL to a Canvas Course'
# Found article ID '982' in tracking dict. Using Google Doc ID: 1CJnKfJ-_pWwfxlnIX9O3Bj7XU76Vzerw128Uq5dkNXI
# Successfully updated Google Doc (ID: 1CJnKfJ-_pWwfxlnIX9O3Bj7XU76Vzerw128Uq5dkNXI) for article 'Add or Remove Forwarding Email in MCommunity - Support Staff'
# Found article ID '6627' in tracking dict. Using Google Doc ID: 1AoKSAb6ORdkQT1zDaR1lC99ONAsKAJFDnZmN4r9sLTw
# Successfully updated Google Doc (ID: 1AoKSAb6ORdkQT1zDaR1lC99ONAsKAJFDnZmN4r9sLTw) for article 'Add or Remove Mail Forwarding From umich.edu to med.umich.edu'
# Found article ID '6739' in tracking dict. Using Google Doc ID: 1Ui_drx_Cvt2tKs2XfDmXrzPF3esmE5wrIS3C0MAk6kg
# Successfully updated Google Doc (ID: 1Ui_drx_Cvt2tKs2XfDmXrzPF3esmE5wrIS3C0MAk6kg) for article 'Add or Remove a Delegate Time Approver'
# Found article ID '10648' in tracking dict. Using Google Doc ID: 17namuGwbSuBJgPsDgtBrlSrnMI54jTD1xwP0PiayTc0
# Successfully updated Google Doc (ID: 17namuGwbSuBJgPsDgtBrlSrnMI54jTD1xwP0PiayTc0) for article 'Add-on Security Software Alerting of Attacks While on M-Wireless'
# Found article ID '1055' in tracking dict. Using Google Doc ID: 1y4NfUkk8Py3FmWECY-rI38EpyCBRZi_uUrgW17Yu7ys
# Successfully updated Google Doc (ID: 1y4NfUkk8Py3FmWECY-rI38EpyCBRZi_uUrgW17Yu7ys) for article 'Add/Remove Software in Otto'
# Found article ID '3566' in tracking dict. Using Google Doc ID: 1YEanffeYdHAilYdg7jYId8bgi-VjGjFcOHh6b_BrzBs
# Successfully updated Google Doc (ID: 1YEanffeYdHAilYdg7jYId8bgi-VjGjFcOHh6b_BrzBs) for article 'Adding Account-Level and Sub-Account Administrators to Canvas (Support Staff)'
# Found article ID '311' in tracking dict. Using Google Doc ID: 1UzJYCwu55k-3HAmQGnY_aHs8fRjDAWybkFDGRTSmQrQ
# Successfully updated Google Doc (ID: 1UzJYCwu55k-3HAmQGnY_aHs8fRjDAWybkFDGRTSmQrQ) for article 'Adding People (Students, Teachers, TAs, etc) to Canvas Courses Manually (Support Staff)'
# Found article ID '1083' in tracking dict. Using Google Doc ID: 1EFcxO1NfPBmVSo1O124L7YXGmGGhrrGu9By93kD86XY
# Successfully updated Google Doc (ID: 1EFcxO1NfPBmVSo1O124L7YXGmGGhrrGu9By93kD86XY) for article 'Adding a Group Owner in MCommunity - Policy'
# Found article ID '11635' in tracking dict. Using Google Doc ID: 1E319d0IGFqw8pmpsxdm7iWCoxjfnEl7oEdzexMlvvWA
# Successfully updated Google Doc (ID: 1E319d0IGFqw8pmpsxdm7iWCoxjfnEl7oEdzexMlvvWA) for article 'Adding a Service to the ITS Service Catalog'
# Found article ID '7308' in tracking dict. Using Google Doc ID: 12ANXdgFSlPo9_N3-hhXwLPXIyZnYqWFQh1JQXUO5tMc
# Successfully updated Google Doc (ID: 12ANXdgFSlPo9_N3-hhXwLPXIyZnYqWFQh1JQXUO5tMc) for article 'Adding and Searching for Comments in a TeamDynamix Ticket'
# Found article ID '58' in tracking dict. Using Google Doc ID: 18NafiYMyHbjCac7erMCYeXEPv0vdRudr4ic24kUIqd4
# Successfully updated Google Doc (ID: 18NafiYMyHbjCac7erMCYeXEPv0vdRudr4ic24kUIqd4) for article 'Adding/Removing Members from MCommunity Groups - Who Updates the Groups?'
# Found article ID '4681' in tracking dict. Using Google Doc ID: 1EXKrTkAHaLEjRco0shZJ_PBDbHF0WGMZZ6eMDLpNfro
# Successfully updated Google Doc (ID: 1EXKrTkAHaLEjRco0shZJ_PBDbHF0WGMZZ6eMDLpNfro) for article 'Adjustment or Modification to CNAME'
# Found article ID '791' in tracking dict. Using Google Doc ID: 1aT-7PV5jz1SxyCE6LzZwSupHC9iHIztzx398W9wvSWg
# Successfully updated Google Doc (ID: 1aT-7PV5jz1SxyCE6LzZwSupHC9iHIztzx398W9wvSWg) for article 'Administrative Accounts for Support Staff in MiWorkspace'
# Found article ID '9988' in tracking dict. Using Google Doc ID: 1DZUSBnqufQSgjtXSDLsuaKpbgh0V-lTvCvLUwkEMd7g
# Successfully updated Google Doc (ID: 1DZUSBnqufQSgjtXSDLsuaKpbgh0V-lTvCvLUwkEMd7g) for article 'Adobe "Failed To Load Document"'
# Found article ID '3612' in tracking dict. Using Google Doc ID: 1Cj0Bpf9iKVO9IK3z3GHsK98tuS3l9a_BmeHL93OVazQ
# Successfully updated Google Doc (ID: 1Cj0Bpf9iKVO9IK3z3GHsK98tuS3l9a_BmeHL93OVazQ) for article 'Adobe Access Denied'
# Found article ID '6971' in tracking dict. Using Google Doc ID: 106hbJ1Iksi7kSzKbtqIhkt7Dm1bB48v1KSLdG0uDx6M
# Successfully updated Google Doc (ID: 106hbJ1Iksi7kSzKbtqIhkt7Dm1bB48v1KSLdG0uDx6M) for article 'Adobe Acrobat DC: "Any form fields that have the same name in the merged document are now merged into one field" Error'
# Found article ID '970' in tracking dict. Using Google Doc ID: 1R6OfeXagCrb5rbvdg5OXYXF8a01hBa8sCdUT8O7FzOo
# Successfully updated Google Doc (ID: 1R6OfeXagCrb5rbvdg5OXYXF8a01hBa8sCdUT8O7FzOo) for article 'Adobe Creative Campus License Agreement'
# Found article ID '443' in tracking dict. Using Google Doc ID: 1HUAG_nui9Z1e1OjLpVqhjm-rfb8yXh07uePKrH66_9g
# Successfully updated Google Doc (ID: 1HUAG_nui9Z1e1OjLpVqhjm-rfb8yXh07uePKrH66_9g) for article 'Adobe Device Licenses in MiWorkspace'
# Found article ID '11159' in tracking dict. Using Google Doc ID: 1H7km3EgiLtMyArAu3NAxDIMJlfDuK4Y5EnDWeJ71JkI
# Successfully updated Google Doc (ID: 1H7km3EgiLtMyArAu3NAxDIMJlfDuK4Y5EnDWeJ71JkI) for article 'Adobe Express'
# Found article ID '4495' in tracking dict. Using Google Doc ID: 1JMMnR23wIZVnc2XDCG29VH2foLryOnkkrxEmWJdjPVo
# Successfully updated Google Doc (ID: 1JMMnR23wIZVnc2XDCG29VH2foLryOnkkrxEmWJdjPVo) for article 'Adobe Stock: Purchasing Images & No-Cost Assets'
# Found article ID '9428' in tracking dict. Using Google Doc ID: 1umFnfwzqt_B7vRJyEJoolBLllUCViK737Qc6w_q4gns
# Successfully updated Google Doc (ID: 1umFnfwzqt_B7vRJyEJoolBLllUCViK737Qc6w_q4gns) for article 'Adobe Substance'
# Found article ID '10263' in tracking dict. Using Google Doc ID: 1Rno3wHmgEEBi8zZNc-ALfcY4RI1XAe1I2Wi28SKHwts
# Successfully updated Google Doc (ID: 1Rno3wHmgEEBi8zZNc-ALfcY4RI1XAe1I2Wi28SKHwts) for article 'Advanced Dropbox Sync Solutions and Troubleshooting'
# Found article ID '3004' in tracking dict. Using Google Doc ID: 1oFYyP4ux2_QuAsYWdCjL0JeeT0QrRcCEwx18inD1iSQ
# Successfully updated Google Doc (ID: 1oFYyP4ux2_QuAsYWdCjL0JeeT0QrRcCEwx18inD1iSQ) for article 'All About Zoom Waiting Rooms'
# Found article ID '9142' in tracking dict. Using Google Doc ID: 1CoiEA2oaUO9RVJX9W_BxEOoXPge0ox6B-m3G5wUPT2c
# Successfully updated Google Doc (ID: 1CoiEA2oaUO9RVJX9W_BxEOoXPge0ox6B-m3G5wUPT2c) for article 'Allow Others to Manage and Share Your Zoom Cloud Recordings and Meeting Reports'
# Found article ID '1098' in tracking dict. Using Google Doc ID: 1R_St1KALobZe9FU8n2CXsXjPqvP64Do969dx6pQir5k
# Successfully updated Google Doc (ID: 1R_St1KALobZe9FU8n2CXsXjPqvP64Do969dx6pQir5k) for article 'Allow Pop-Up Windows in Chrome'
# Found article ID '9330' in tracking dict. Using Google Doc ID: 1_LPz2UFI4g5nMmRhulcXSnVZaiUxHcoLILK6imkphIE
# Successfully updated Google Doc (ID: 1_LPz2UFI4g5nMmRhulcXSnVZaiUxHcoLILK6imkphIE) for article 'Allow Pop-Up Windows in Multiple Browsers'
# Found article ID '1341' in tracking dict. Using Google Doc ID: 10S6M8fFWkNbwdOWErsjV95LvSBa4TfFpK7LycZKxKz8
# Successfully updated Google Doc (ID: 10S6M8fFWkNbwdOWErsjV95LvSBa4TfFpK7LycZKxKz8) for article 'Allow Pop-Up Windows in Safari'
# Found article ID '10220' in tracking dict. Using Google Doc ID: 1D0sZAxHuR2Zep0-HuIhqMYbTbC1wEDL9vaUHxjOy5Gk
# Successfully updated Google Doc (ID: 1D0sZAxHuR2Zep0-HuIhqMYbTbC1wEDL9vaUHxjOy5Gk) for article 'Alternative Hosts Automatically Set Up for Zoom Meeting Unintentionally'
# Found article ID '11474' in tracking dict. Using Google Doc ID: 12uSYXKH-_4Ogr0pWtqSS9JBEWQpccDGeJs2PHSfZi_g
# Successfully updated Google Doc (ID: 12uSYXKH-_4Ogr0pWtqSS9JBEWQpccDGeJs2PHSfZi_g) for article 'Alternatives If Google Settings Of Compromised Account Are Not Checked'
# Found article ID '8440' in tracking dict. Using Google Doc ID: 1nBFQNVwa3OlNqCUjnM9qZx7N1AdCXI9JCEsbLS-VHv8
# Successfully updated Google Doc (ID: 1nBFQNVwa3OlNqCUjnM9qZx7N1AdCXI9JCEsbLS-VHv8) for article 'Alumni & Retiree MPrint Accounts'
# Found article ID '744' in tracking dict. Using Google Doc ID: 1Q8oXVuMQyn-OUza8c3TvtfWTAXKeh7wV3PbdIn9RoeQ
# Successfully updated Google Doc (ID: 1Q8oXVuMQyn-OUza8c3TvtfWTAXKeh7wV3PbdIn9RoeQ) for article 'Alumni Self-Service Uniqname Creation'
# Found article ID '719' in tracking dict. Using Google Doc ID: 1wPLBcRh8NM4PrlGpQitX-gD7y7ib2U44w-nmF2EmPZY
# Successfully updated Google Doc (ID: 1wPLBcRh8NM4PrlGpQitX-gD7y7ib2U44w-nmF2EmPZY) for article 'Alumni Status in MCommunity'
# Found article ID '9900' in tracking dict. Using Google Doc ID: 1MnKcjcFea0JmARwSrkPMCPgsyofCIPAircEkmfsMYw4
# Successfully updated Google Doc (ID: 1MnKcjcFea0JmARwSrkPMCPgsyofCIPAircEkmfsMYw4) for article 'Alumni Unable to Access Alumni Directory'
# Found article ID '709' in tracking dict. Using Google Doc ID: 1x3Ba8PYRYzOdtq3Ns6tlMKvN1jS34pnpvHo-SpKESY4
# Successfully updated Google Doc (ID: 1x3Ba8PYRYzOdtq3Ns6tlMKvN1jS34pnpvHo-SpKESY4) for article 'Alumni Without Uniqname (Creation Gap)'
# Found article ID '11701' in tracking dict. Using Google Doc ID: 1v8m8CLa7v8Ye5zm6Mscf_CHKf9RvSfoO-t5JF7WUvG0
# Successfully updated Google Doc (ID: 1v8m8CLa7v8Ye5zm6Mscf_CHKf9RvSfoO-t5JF7WUvG0) for article 'Amazon Connect Callbacks and Whisper Function Explained (ITS-SC)'
# Found article ID '2985' in tracking dict. Using Google Doc ID: 1Ip1vJ75Vw0Az5JKYxOp7as8kWXOGFOgICyif2jREI70
# Successfully updated Google Doc (ID: 1Ip1vJ75Vw0Az5JKYxOp7as8kWXOGFOgICyif2jREI70) for article 'Amazon Echo/Alexa Device - How to Find the Wireless MAC Address for MSetup'
# Found article ID '11173' in tracking dict. Using Google Doc ID: 1ZQOFrsnm8jqh6sX8hzJ7FQwkEzp7tEaxx9AVSK1l8Bg
# Successfully updated Google Doc (ID: 1ZQOFrsnm8jqh6sX8hzJ7FQwkEzp7tEaxx9AVSK1l8Bg) for article 'Angell Hall Fishbowl Printing: Operating Hours and Tech Availability'
# Found article ID '2840' in tracking dict. Using Google Doc ID: 1Gqmn4hcAKWR7jd-QyS23gJMhD6gmoXtiuLbdd9lsa8M
# Successfully updated Google Doc (ID: 1Gqmn4hcAKWR7jd-QyS23gJMhD6gmoXtiuLbdd9lsa8M) for article 'Annual Personal Data Validation'
# Found article ID '6250' in tracking dict. Using Google Doc ID: 1ICt4xDLB2HsalfjlvAlNFLsdV6mLoSGyapp65CBLMhI
# Successfully updated Google Doc (ID: 1ICt4xDLB2HsalfjlvAlNFLsdV6mLoSGyapp65CBLMhI) for article 'Anti-Virus/Malware for Personal Devices'
# Found article ID '4759' in tracking dict. Using Google Doc ID: 1zZ_jgH2jW0iz0U_VIJxl1SGWXNDBLGkZMLDDZgOlf4w
# Successfully updated Google Doc (ID: 1zZ_jgH2jW0iz0U_VIJxl1SGWXNDBLGkZMLDDZgOlf4w) for article 'Applications Available in the U-M Microsoft Office 365 Licensing'
# Found article ID '10034' in tracking dict. Using Google Doc ID: 1zHDTfpBo4qfSPvfA9JqLszUQKd4SGrR1KUU3NvvBHYI
# Successfully updated Google Doc (ID: 1zHDTfpBo4qfSPvfA9JqLszUQKd4SGrR1KUU3NvvBHYI) for article 'Applying for Graduation'
# Found article ID '35' in tracking dict. Using Google Doc ID: 11uEGsgLABRmDqzNBPapWNST755kAxCCBaC0KYkw9AS0
# Successfully updated Google Doc (ID: 11uEGsgLABRmDqzNBPapWNST755kAxCCBaC0KYkw9AS0) for article 'Approve a Voucher'
# Found article ID '11783' in tracking dict. Using Google Doc ID: 1ByU7n6iPvCBnR2C4tkFAAaov6BKyn53eTI8uN4TgjQM
# Successfully updated Google Doc (ID: 1ByU7n6iPvCBnR2C4tkFAAaov6BKyn53eTI8uN4TgjQM) for article 'Approving Human Subject Incentives Program (HSIP) Requests'
# Found article ID '11735' in tracking dict. Using Google Doc ID: 1I5zY7LIXzWvJ89O48ADFrIYvFzqiBbJwohGd6cuXMXM
# Successfully updated Google Doc (ID: 1I5zY7LIXzWvJ89O48ADFrIYvFzqiBbJwohGd6cuXMXM) for article 'Archive or Delete a TeamDynamix Knowledge Article'
# Found article ID '8738' in tracking dict. Using Google Doc ID: 1EseC-22pcSaxttW4udp7OcMz-5Oqzs-vGb1TRD8KKF4
# Successfully updated Google Doc (ID: 1EseC-22pcSaxttW4udp7OcMz-5Oqzs-vGb1TRD8KKF4) for article 'Are University of Michigan Accounts Provided for Coursera Participants?'
# Found article ID '1221' in tracking dict. Using Google Doc ID: 1wvrM_2I3lJlP96B6J5FQrLLL7ugKGtlNoeTNsjhHp0Y
# Successfully updated Google Doc (ID: 1wvrM_2I3lJlP96B6J5FQrLLL7ugKGtlNoeTNsjhHp0Y) for article 'Asset Tag Request'
# Found article ID '70' in tracking dict. Using Google Doc ID: 1kRrcCj52asL2lmIMNeHEfj3bidLoKuo5dhuTwuFZ9R0
# Successfully updated Google Doc (ID: 1kRrcCj52asL2lmIMNeHEfj3bidLoKuo5dhuTwuFZ9R0) for article 'Assign Incident to M-Reports Assignment Group ITS-IQ-MReports'
# Found article ID '280' in tracking dict. Using Google Doc ID: 1L_ViQKKMxZkwwebo2CK4tjGkUd2ff6uUrhBKdj_Ilck
# Successfully updated Google Doc (ID: 1L_ViQKKMxZkwwebo2CK4tjGkUd2ff6uUrhBKdj_Ilck) for article 'Assign My LINC Training to Employees?'
# Found article ID '235' in tracking dict. Using Google Doc ID: 1zecnyZKUyOSxtJbFtAsPWzfMsT0y7lf1ePpAP0lAuwc
# Successfully updated Google Doc (ID: 1zecnyZKUyOSxtJbFtAsPWzfMsT0y7lf1ePpAP0lAuwc) for article 'Assign Secondary/Proxy Access to a Project/Grant in M-Reports'
# Found article ID '10079' in tracking dict. Using Google Doc ID: 1OehUEkcmRcj2aJm7enJDqBCPg1R9-QjCtFIiNHA5DhM
# Successfully updated Google Doc (ID: 1OehUEkcmRcj2aJm7enJDqBCPg1R9-QjCtFIiNHA5DhM) for article 'Assign a Cart in Marketsite+'
# Found article ID '11179' in tracking dict. Using Google Doc ID: 1znCDj5Xw7dnl-7rHyE9pKVaosYdNTy2NLHyV-u9ZiZc
# Successfully updated Google Doc (ID: 1znCDj5Xw7dnl-7rHyE9pKVaosYdNTy2NLHyV-u9ZiZc) for article 'Assignment Guide for OARS Requests in Pending ITS Authorization State'
# Found article ID '762' in tracking dict. Using Google Doc ID: 1EdtVQz5vxPiY3r9ndNSXr9uCEbgFm1kdpaABrAkAXkg
# Successfully updated Google Doc (ID: 1EdtVQz5vxPiY3r9ndNSXr9uCEbgFm1kdpaABrAkAXkg) for article 'Assignment Guide for OARS incidents'
# Found article ID '10275' in tracking dict. Using Google Doc ID: 1alXAjXQuIER9UNPlD034LYIW6DG2Ict8XRG_HJ69UZ0
# Successfully updated Google Doc (ID: 1alXAjXQuIER9UNPlD034LYIW6DG2Ict8XRG_HJ69UZ0) for article 'Assistance with ACME for TLS/SSL Certificates'
# Found article ID '11532' in tracking dict. Using Google Doc ID: 19RBx6TxceqYfr7NHnvu96cVuIEwuwp6Zv3NZ-4MkacQ
# Successfully updated Google Doc (ID: 19RBx6TxceqYfr7NHnvu96cVuIEwuwp6Zv3NZ-4MkacQ) for article 'Assistance with OARS Batch Uploads'
# Found article ID '32' in tracking dict. Using Google Doc ID: 1wgjDQKMsVEqBNoYYKeVXdVGU2cRMgekhlsMIuXTQj8Q
# Successfully updated Google Doc (ID: 1wgjDQKMsVEqBNoYYKeVXdVGU2cRMgekhlsMIuXTQj8Q) for article 'Assistance with a Quote To Order (QTO)'
# Found article ID '6679' in tracking dict. Using Google Doc ID: 1bZUzzwzwDSApVE7aW3L5dBtKW4nP0uV5oSfQCUQu9GY
# Successfully updated Google Doc (ID: 1bZUzzwzwDSApVE7aW3L5dBtKW4nP0uV5oSfQCUQu9GY) for article 'Authorization Failed, Access Denied, or Blank Screen When Authenticating with Google Drive in Canvas'
# Found article ID '105' in tracking dict. Using Google Doc ID: 1oDZ84OT6ETNDgbTl67rsUJdsk0rMvcVP5CT8nTS5R8I
# Successfully updated Google Doc (ID: 1oDZ84OT6ETNDgbTl67rsUJdsk0rMvcVP5CT8nTS5R8I) for article 'Authorize Parent/Guardian to View Student Account Information'
# Found article ID '4310' in tracking dict. Using Google Doc ID: 1Yt3tkll08XQCeRSYmP8f_EKohs-KecPDFbpiwQ7tijw
# Successfully updated Google Doc (ID: 1Yt3tkll08XQCeRSYmP8f_EKohs-KecPDFbpiwQ7tijw) for article 'Autodesk AutoCAD / Revit - Facilities & Operations (F&O)'
# Found article ID '9877' in tracking dict. Using Google Doc ID: 1y7zlW96W1GB3PurAw9xeg-UXfZhYQAWjtvg1rE8AU5A
# Successfully updated Google Doc (ID: 1y7zlW96W1GB3PurAw9xeg-UXfZhYQAWjtvg1rE8AU5A) for article 'Automatically Issue and Renew InCommon Certificates via Certbot (ACME) Without a Web Server or Domain Control Validation (DCV)'
# Found article ID '4546' in tracking dict. Using Google Doc ID: 1LshtB9NNvdOjgLNP5Zki4doHV9uORIQ7xpz2ymuOKAI
# Successfully updated Google Doc (ID: 1LshtB9NNvdOjgLNP5Zki4doHV9uORIQ7xpz2ymuOKAI) for article 'Automatically Share Zoom Cloud Recording with Someone Else'
# Found article ID '4515' in tracking dict. Using Google Doc ID: 1hxi2EhnONkJol54yUr-RBTv__RdHxcIuolCfZILDXfM
# Successfully updated Google Doc (ID: 1hxi2EhnONkJol54yUr-RBTv__RdHxcIuolCfZILDXfM) for article 'BCA Downtime Application'
# Found article ID '12448' in tracking dict. Using Google Doc ID: 1L5dgUWm9y4w4abobWoj_ip54g_Q0xy0_Fi-7Y1ZXM0s
# Successfully updated Google Doc (ID: 1L5dgUWm9y4w4abobWoj_ip54g_Q0xy0_Fi-7Y1ZXM0s) for article 'BIOS Password Needed to Recover Windows - July 19'
# Found article ID '9117' in tracking dict. Using Google Doc ID: 1sM4Cbz6LTnk4Ebxj42OZ3gHIQR3pb1_TrW_EOjUcbd8
# Successfully updated Google Doc (ID: 1sM4Cbz6LTnk4Ebxj42OZ3gHIQR3pb1_TrW_EOjUcbd8) for article 'BO - Scheduling to Google Drive Fails'
# Found article ID '11157' in tracking dict. Using Google Doc ID: 1xw-aFhl0vL2Dg2LUfWZz3YccGCavzBKTGqzm_yH1kV4
# Successfully updated Google Doc (ID: 1xw-aFhl0vL2Dg2LUfWZz3YccGCavzBKTGqzm_yH1kV4) for article 'BTN Content Access: On-Campus Networks vs. VPN Ranges'
# Found article ID '967' in tracking dict. Using Google Doc ID: 1_HVRqduZw6WxaIUVe5vuIQcHm9ng-u0Fu3PB5YiwzdY
# Successfully updated Google Doc (ID: 1_HVRqduZw6WxaIUVe5vuIQcHm9ng-u0Fu3PB5YiwzdY) for article 'Basic MWireless Troubleshooting'
# Found article ID '7398' in tracking dict. Using Google Doc ID: 124-OcDGd8NIU8D1tGafZSO3ZnrJbEucB5NQ8hUTcbQQ
# Successfully updated Google Doc (ID: 124-OcDGd8NIU8D1tGafZSO3ZnrJbEucB5NQ8hUTcbQQ) for article 'Basic Troubleshooting for Issues with Google Services'
# Found article ID '7343' in tracking dict. Using Google Doc ID: 1shJvuAOd-CAc8gMEmMrLLrD3dYNi5TtUJhdfs6WMn8o
# Successfully updated Google Doc (ID: 1shJvuAOd-CAc8gMEmMrLLrD3dYNi5TtUJhdfs6WMn8o) for article 'Benefits Self-Service (aka eBenefits) - Benefits Summary Review Not Available'
# Found article ID '9023' in tracking dict. Using Google Doc ID: 1AGxGaIhfPc7BTTH52zM9vLumPJHIGoouHkUt1jSse_E
# Successfully updated Google Doc (ID: 1AGxGaIhfPc7BTTH52zM9vLumPJHIGoouHkUt1jSse_E) for article 'BeyondTrust (Bomgar): Generating Monthly Reports'
# Found article ID '979' in tracking dict. Using Google Doc ID: 1psPvz8qZpQb7WX2JpC71WdQJm3i4G5IpICM47sUgTOU
# Successfully updated Google Doc (ID: 1psPvz8qZpQb7WX2JpC71WdQJm3i4G5IpICM47sUgTOU) for article 'BeyondTrust (Bomgar): Request Access as a Remote Support Representative'
# Found article ID '5519' in tracking dict. Using Google Doc ID: 1doyoSTUe9560WzDSqMHmTpDZ2Qj2QZ0e91tCRFbZLwM
# Successfully updated Google Doc (ID: 1doyoSTUe9560WzDSqMHmTpDZ2Qj2QZ0e91tCRFbZLwM) for article 'Billing Questions/Charges for ITS Infrastructure Services'
# Found article ID '11593' in tracking dict. Using Google Doc ID: 1ggs88ugi5a0DzugNCvYg8s2BiFtRtB7chiAdXLYETdk
# Successfully updated Google Doc (ID: 1ggs88ugi5a0DzugNCvYg8s2BiFtRtB7chiAdXLYETdk) for article 'Biorender License'
# Found article ID '4535' in tracking dict. Using Google Doc ID: 1VnPXUdk5_Uau1M8ezPkdky5QNOnaP_jMhrhJGwzWHPU
# Successfully updated Google Doc (ID: 1VnPXUdk5_Uau1M8ezPkdky5QNOnaP_jMhrhJGwzWHPU) for article 'Bitlocker Recovery Key'
# Found article ID '6816' in tracking dict. Using Google Doc ID: 1aSsy_mRF9sgwSTOIqZYnTXY9jVHsQGLe9JG_JqniU5U
# Successfully updated Google Doc (ID: 1aSsy_mRF9sgwSTOIqZYnTXY9jVHsQGLe9JG_JqniU5U) for article 'Bitlocker Recovery Key for Sites@Home computers'
# Found article ID '4687' in tracking dict. Using Google Doc ID: 1UDhA8m0HySXR1yyiXw_4aAPYhqV_9FDoNk9Wjw3hmVI
# Successfully updated Google Doc (ID: 1UDhA8m0HySXR1yyiXw_4aAPYhqV_9FDoNk9Wjw3hmVI) for article 'Blank Time Reporting Page: Missing Time Reporting Options'
# Found article ID '3501' in tracking dict. Using Google Doc ID: 1xBZQ1YbOwt_OaZEIGU03-oQVdR1zAv2ZNbsPcxFC9_8
# Successfully updated Google Doc (ID: 1xBZQ1YbOwt_OaZEIGU03-oQVdR1zAv2ZNbsPcxFC9_8) for article 'Blocking Advertising Alerts on the Computer'
# Found article ID '6669' in tracking dict. Using Google Doc ID: 1qOMSdDxEAxvsr3TgpR6gl4SScm6eTB8EKzzKAH16i9c
# Successfully updated Google Doc (ID: 1qOMSdDxEAxvsr3TgpR6gl4SScm6eTB8EKzzKAH16i9c) for article 'Blue Bucks Account Support'
# Found article ID '7821' in tracking dict. Using Google Doc ID: 1Q8I1TNnRRepW3MjVvDnMCVWO_lt49SM49arHoqr3gYQ
# Successfully updated Google Doc (ID: 1Q8I1TNnRRepW3MjVvDnMCVWO_lt49SM49arHoqr3gYQ) for article 'Blue Light Repairs for Emergency Phones in Parking Structures or Parking Lots'
# Found article ID '618' in tracking dict. Using Google Doc ID: 1HRZ50phsvqakZ9C3HMlTSlPlvK2Tj6U_hccAjNnAY6s
# Successfully updated Google Doc (ID: 1HRZ50phsvqakZ9C3HMlTSlPlvK2Tj6U_hccAjNnAY6s) for article 'BlueCat Address Manager (was Proteus)'
# Found article ID '3996' in tracking dict. Using Google Doc ID: 12F8B5JDXnjZFUx2NjcXNYaWPLpsSS6hFMPJ6cfl8Q0o
# Successfully updated Google Doc (ID: 12F8B5JDXnjZFUx2NjcXNYaWPLpsSS6hFMPJ6cfl8Q0o) for article 'Boomerang for Gmail Alternatives'
# Found article ID '11762' in tracking dict. Using Google Doc ID: 1HVvfH9x76Lqreu3IOvMGk60eNf782h-cRLlCOD-Jvwk
# Successfully updated Google Doc (ID: 1HVvfH9x76Lqreu3IOvMGk60eNf782h-cRLlCOD-Jvwk) for article 'Box is No Longer a U-M Service'
# Found article ID '1219' in tracking dict. Using Google Doc ID: 1VcJUoEPavWXn_nRqkaxdzVzFSYG6F8oEcCVX4ORxPcU
# Successfully updated Google Doc (ID: 1VcJUoEPavWXn_nRqkaxdzVzFSYG6F8oEcCVX4ORxPcU) for article 'Browser: Stale Request Error'
# Found article ID '8439' in tracking dict. Using Google Doc ID: 1FZePOsrwhqr-_sVjLJfbrYqw3v9zUW4uihkiqByohn8
# Successfully updated Google Doc (ID: 1FZePOsrwhqr-_sVjLJfbrYqw3v9zUW4uihkiqByohn8) for article 'Bulk Delete Multiple Gmail Messages in a Given Date Range'
# Found article ID '101' in tracking dict. Using Google Doc ID: 1supbHpz0K3k3cTrBjIFdjecxX0pPzqHjE9Nts6xfFY0
# Successfully updated Google Doc (ID: 1supbHpz0K3k3cTrBjIFdjecxX0pPzqHjE9Nts6xfFY0) for article 'Business Objects - "Account information not recognized: ...." Error'
# Found article ID '9116' in tracking dict. Using Google Doc ID: 1P5Z_KXIbCtNU_Eh0wit3dJ-5-4iPMzr4KVmj6boMnho
# Successfully updated Google Doc (ID: 1P5Z_KXIbCtNU_Eh0wit3dJ-5-4iPMzr4KVmj6boMnho) for article 'Business Objects Search Not Available/ display error'
# Found article ID '60' in tracking dict. Using Google Doc ID: 1BkddWDguwCmD8UGEwKM5VVr6P8K1c-vzOAsLsLp42CI
# Successfully updated Google Doc (ID: 1BkddWDguwCmD8UGEwKM5VVr6P8K1c-vzOAsLsLp42CI) for article 'BusinessObjects Reporting Questions and Assistance with Queries and Reports - Support Staff'
# Found article ID '12065' in tracking dict. Using Google Doc ID: 1Z2T4OrzTOxgl_XEfwTrlIt4m1XrOlfWH0zYIgl13k7k
# Successfully updated Google Doc (ID: 1Z2T4OrzTOxgl_XEfwTrlIt4m1XrOlfWH0zYIgl13k7k) for article 'Bypass Code Needed for Platform Authenticator-Enrolled Users'
# Found article ID '4866' in tracking dict. Using Google Doc ID: 1S2Ivpwsk0t8dgQDl32GItOlkwmHrZsIbysOmGnTdFmA
# Successfully updated Google Doc (ID: 1S2Ivpwsk0t8dgQDl32GItOlkwmHrZsIbysOmGnTdFmA) for article 'CAEN Computing Resources'
# Found article ID '8205' in tracking dict. Using Google Doc ID: 1U19OzE_Pj_F6-FfYmCRTPisGWNbefntWB0i6d3X4z4M
# Successfully updated Google Doc (ID: 1U19OzE_Pj_F6-FfYmCRTPisGWNbefntWB0i6d3X4z4M) for article 'CC'd TeamDynamix Email Recipients are Added as Contacts'
# Found article ID '8799' in tracking dict. Using Google Doc ID: 1yj5Aibit1ogdMnLgoEmeWhbEL8z9nXkxBh8DqCi8s6Q
# Successfully updated Google Doc (ID: 1yj5Aibit1ogdMnLgoEmeWhbEL8z9nXkxBh8DqCi8s6Q) for article 'COBRA ID is in Suspense -- Dup Case to be Corrected'
# Found article ID '3221' in tracking dict. Using Google Doc ID: 1-KAN5qk62eVuBuzRLkZn3M_I8dbOxGWnT0nq50zS7mk
# Successfully updated Google Doc (ID: 1-KAN5qk62eVuBuzRLkZn3M_I8dbOxGWnT0nq50zS7mk) for article 'CS2K Telephone Line Testing'
# Found article ID '10141' in tracking dict. Using Google Doc ID: 1sUvjpgrimJ14aB1MiZWPhbpGC202x06VBuBMlsEtv7w
# Successfully updated Google Doc (ID: 1sUvjpgrimJ14aB1MiZWPhbpGC202x06VBuBMlsEtv7w) for article 'CSRF Token Verification Failed'
# Found article ID '3855' in tracking dict. Using Google Doc ID: 1cECK1cwBjb6-wPdSKz5gtszDI-uYH94Ev6Z2Jk5oAYQ
# Successfully updated Google Doc (ID: 1cECK1cwBjb6-wPdSKz5gtszDI-uYH94Ev6Z2Jk5oAYQ) for article 'CTools Has Retired'
# Found article ID '6129' in tracking dict. Using Google Doc ID: 1KnxtRXO_ATOkj8jzeNcEwsJ08ZumZ1eUDAhiBPHC9Hc
# Successfully updated Google Doc (ID: 1KnxtRXO_ATOkj8jzeNcEwsJ08ZumZ1eUDAhiBPHC9Hc) for article 'Cable Modem/Router Combo - Northwood Apartments'
# Found article ID '4666' in tracking dict. Using Google Doc ID: 1RZd9ZEu7erixywif8BlwNWrkEv61XWUTdOnr4qdasuM
# Successfully updated Google Doc (ID: 1RZd9ZEu7erixywif8BlwNWrkEv61XWUTdOnr4qdasuM) for article 'Call In to a Zoom Meeting or Webinar on a Phone'
# Found article ID '6882' in tracking dict. Using Google Doc ID: 1LwuPIlS21PdCTMKyWPrs95yXXe4gIYC83DyxYMXUfdM
# Successfully updated Google Doc (ID: 1LwuPIlS21PdCTMKyWPrs95yXXe4gIYC83DyxYMXUfdM) for article 'Camp Michigania Network and Internet Support'
# Found article ID '8025' in tracking dict. Using Google Doc ID: 1mVcfW2j27KNRackP7FfLVDkRzHp9sXnxyk17vInxnmI
# Successfully updated Google Doc (ID: 1mVcfW2j27KNRackP7FfLVDkRzHp9sXnxyk17vInxnmI) for article 'Campus Computing - Granting a Software Exception Request'
# Found article ID '370' in tracking dict. Using Google Doc ID: 1UVpBiRysQgzUt6ztc_BnpBcFSVEYJ9Qxv_baB2sslQo
# Successfully updated Google Doc (ID: 1UVpBiRysQgzUt6ztc_BnpBcFSVEYJ9Qxv_baB2sslQo) for article 'Campus Computing Sites (CCS) - Locations and Access'
# Found article ID '2829' in tracking dict. Using Google Doc ID: 10AfEJFXfTxQVAV-ILpyZNaPb_AuMqWAiLdb7G3fsbmQ
# Successfully updated Google Doc (ID: 10AfEJFXfTxQVAV-ILpyZNaPb_AuMqWAiLdb7G3fsbmQ) for article 'Campus Computing Sites - New/Update Software Request'
# Found article ID '4892' in tracking dict. Using Google Doc ID: 1zL5sgcFF8ldf_vHjUlHxevn2NwgBX4e5M0d_RQ-PhmE
# Successfully updated Google Doc (ID: 1zL5sgcFF8ldf_vHjUlHxevn2NwgBX4e5M0d_RQ-PhmE) for article 'Campus Computing Sites Availability'
# Found article ID '10860' in tracking dict. Using Google Doc ID: 1Usmhtt0EAg9qj3dRmtIdAeiBq5hMeTP12E10KCbbFgc
# Successfully updated Google Doc (ID: 1Usmhtt0EAg9qj3dRmtIdAeiBq5hMeTP12E10KCbbFgc) for article 'Campus Exclusion List Removal'
# Found article ID '3465' in tracking dict. Using Google Doc ID: 1QWxB654g7LWyzACesh7saNt0BYkmNRqDxu5andNN8vQ
# Successfully updated Google Doc (ID: 1QWxB654g7LWyzACesh7saNt0BYkmNRqDxu5andNN8vQ) for article 'Can Email From Before the U-M Google Transition Be Accessed or Recovered?'
# Found article ID '6077' in tracking dict. Using Google Doc ID: 1yDMWZVM60cd8nRV_pWpwCvDP98petpe7cVgFygERxA4
# Successfully updated Google Doc (ID: 1yDMWZVM60cd8nRV_pWpwCvDP98petpe7cVgFygERxA4) for article 'Can HD be Enabled on My Zoom Account? 1080p'
# Found article ID '8309' in tracking dict. Using Google Doc ID: 12NARlQelsHBtM4fykatv3yucoa4-28l_Gs79yUHGXpE
# Successfully updated Google Doc (ID: 12NARlQelsHBtM4fykatv3yucoa4-28l_Gs79yUHGXpE) for article 'Can I Use My @umich.edu Email Address to Create a Personal Box Account?'
# Found article ID '10035' in tracking dict. Using Google Doc ID: 1G44bAPM9HfuO6QC8nMGIit6PEmQe4zWpcTer7xSzH0Y
# Successfully updated Google Doc (ID: 1G44bAPM9HfuO6QC8nMGIit6PEmQe4zWpcTer7xSzH0Y) for article 'Can Incorrect Google Maps Info Be Corrected By ITS?'
# Found article ID '4064' in tracking dict. Using Google Doc ID: 1lT42IOzCauZaOCy_dfOwk8Qc0H-AnDDAzF2DSxEr6vE
# Successfully updated Google Doc (ID: 1lT42IOzCauZaOCy_dfOwk8Qc0H-AnDDAzF2DSxEr6vE) for article 'Can Multiple U-M Careers Accounts be Combined or Deleted?'
# Found article ID '7237' in tracking dict. Using Google Doc ID: 1DsvtgTJGe3escPRoR6rw9T4HzwYWX0_bSnVnDGHZwWc
# Successfully updated Google Doc (ID: 1DsvtgTJGe3escPRoR6rw9T4HzwYWX0_bSnVnDGHZwWc) for article 'Can Personal Wifi Routers be Used on Campus?'
# Found article ID '6271' in tracking dict. Using Google Doc ID: 1DemJhEDDUHCJlk70ajbQGxtmMcZ6FtY3pgI_OXj8ORE
# Successfully updated Google Doc (ID: 1DemJhEDDUHCJlk70ajbQGxtmMcZ6FtY3pgI_OXj8ORE) for article 'Can W-4 be Accessed Prior to Start Date?'
# Found article ID '10723' in tracking dict. Using Google Doc ID: 1BL81o0uG9hqzs0bnXFYclPEyljTcZRkwFOxUkqQOPQo
# Successfully updated Google Doc (ID: 1BL81o0uG9hqzs0bnXFYclPEyljTcZRkwFOxUkqQOPQo) for article 'Can't Add Item to Cart on Marketsite+, "undefined" Message OR Login/Continue as Guest Prompt'
# Found article ID '8724' in tracking dict. Using Google Doc ID: 1acdb04FQGG6M7QdRekkUwcjsCSmYvcTwYEljPG9ayVI
# Successfully updated Google Doc (ID: 1acdb04FQGG6M7QdRekkUwcjsCSmYvcTwYEljPG9ayVI) for article 'Can't Connect Tableau to Google Sheet on Google Shared Drive'
# Found article ID '5625' in tracking dict. Using Google Doc ID: 1V9z2dyatfZBfNjUB1QTjEbbOIP5TCNMFWItMcDOJWF4
# Successfully updated Google Doc (ID: 1V9z2dyatfZBfNjUB1QTjEbbOIP5TCNMFWItMcDOJWF4) for article 'Can't Find Zoom Meeting in My Meeting List / Meeting Missing'
# Found article ID '792' in tracking dict. Using Google Doc ID: 17b3VBVmKgLGeM1r5KAN-J4J4xZ-BKvHtIChIQZHiEd0
# Successfully updated Google Doc (ID: 17b3VBVmKgLGeM1r5KAN-J4J4xZ-BKvHtIChIQZHiEd0) for article 'Can't Log Into CCURE'
# Found article ID '9972' in tracking dict. Using Google Doc ID: 1-sSERiuR68x0C5hOMTqgXlHwzjyWu0R4V4i9htu_b0g
# Successfully updated Google Doc (ID: 1-sSERiuR68x0C5hOMTqgXlHwzjyWu0R4V4i9htu_b0g) for article 'Can't Log in to Atlassian Products (Trello, Jira, Confluence, etc.)'
# Found article ID '11172' in tracking dict. Using Google Doc ID: 1UQZbZqO6SKKzO1DavJ4anoKGvhtoTpO5np30XSqLVsU
# Successfully updated Google Doc (ID: 1UQZbZqO6SKKzO1DavJ4anoKGvhtoTpO5np30XSqLVsU) for article 'Can't Log in to Pantheon'
# ...
# Successfully updated Google Doc (ID: 1hzZ1mMt516DpuAIwkHWDGDxYtfyG_gSG9tQE8sRL2eQ) for article 'Zoom: Language Interpretation and Translation in Meetings and Webinars'
# Found article ID '3442' in tracking dict. Using Google Doc ID: 1nKqVi4QCG8rzTIFyLMcUfrzndOcGoTtXPiBhS7HFGLI
# Successfully updated Google Doc (ID: 1nKqVi4QCG8rzTIFyLMcUfrzndOcGoTtXPiBhS7HFGLI) for article 'Zoom: Large Meeting License Requests'
# Found article ID '1050' in tracking dict. Using Google Doc ID: 1I7HAlpwHqTpmPnhOsm5Ck1-vPtm3Ut-XYuNKweLziJk
# Successfully updated Google Doc (ID: 1I7HAlpwHqTpmPnhOsm5Ck1-vPtm3Ut-XYuNKweLziJk) for article 'Zoom: Managing Breakout Rooms in a Meeting'
# Found article ID '163' in tracking dict. Using Google Doc ID: 1_UUjVfQT3AXGiuapP-twvpb78fayeoj0n81Qn6twKjY
# Successfully updated Google Doc (ID: 1_UUjVfQT3AXGiuapP-twvpb78fayeoj0n81Qn6twKjY) for article 'Zoom: Meeting and Webinar Participant/Attendee Limits'
# Found article ID '1024' in tracking dict. Using Google Doc ID: 16MLE2x5-DyRnpmZ_eNiYD_XMeUrRP3kpofz5h6ZaIs0
# Successfully updated Google Doc (ID: 16MLE2x5-DyRnpmZ_eNiYD_XMeUrRP3kpofz5h6ZaIs0) for article 'Zoom: Meetings vs. Webinars Comparison'
# Found article ID '1404' in tracking dict. Using Google Doc ID: 1PfVmgQSzUvjForpTOPhqXoi7TjguRTm8K_1q2E31WWs
# Successfully updated Google Doc (ID: 1PfVmgQSzUvjForpTOPhqXoi7TjguRTm8K_1q2E31WWs) for article 'Zoom: Process for Manually Granting a Webinar or Large Meeting License (Tier 3 Staff)'
# Found article ID '1020' in tracking dict. Using Google Doc ID: 1JL8o32jggg3q5lvesKRTxvROLrzXo6Ml-2bzr9S42Ac
# Successfully updated Google Doc (ID: 1JL8o32jggg3q5lvesKRTxvROLrzXo6Ml-2bzr9S42Ac) for article 'Zoom: Record Meetings and Save to Cloud or Local Computer (Zoom Recording)'
# Found article ID '1320' in tracking dict. Using Google Doc ID: 1umvDklklfcRmtk_mJPaZl8H73T63SQi9H9-YHM03ITM
# Successfully updated Google Doc (ID: 1umvDklklfcRmtk_mJPaZl8H73T63SQi9H9-YHM03ITM) for article 'Zoom: Request a Webinar License or Change Webinar Participant Limits'
# Found article ID '4589' in tracking dict. Using Google Doc ID: 1hPmTwHi-QlHrqs6IF2aWgZVCjeDI_G1ygVookUdKnek
# Successfully updated Google Doc (ID: 1hPmTwHi-QlHrqs6IF2aWgZVCjeDI_G1ygVookUdKnek) for article 'Zoom: Require That All Meetings Are Secured With One Security Option'
# Found article ID '1065' in tracking dict. Using Google Doc ID: 11oyFk-5K2lJJSgXyMPEYjns3-J8spOWtQVJBtwJdM7U
# Successfully updated Google Doc (ID: 11oyFk-5K2lJJSgXyMPEYjns3-J8spOWtQVJBtwJdM7U) for article 'Zoom: Schedule a Meeting for Someone Else to Host (Delegate, Scheduling Privilege)'
# Found article ID '150' in tracking dict. Using Google Doc ID: 1JQ3DEeP_a9BfBxDXWk_YTX0tnoKoF9vKK--W85r5qNo
# Successfully updated Google Doc (ID: 1JQ3DEeP_a9BfBxDXWk_YTX0tnoKoF9vKK--W85r5qNo) for article 'Zoom: Schedule a Meeting on the Web (zoom.umich.edu)'
# Found article ID '11523' in tracking dict. Using Google Doc ID: 1psNbOHZdnx-gMXG66lifXNdNkIVTbzB-XZSD1WKah6I
# Successfully updated Google Doc (ID: 1psNbOHZdnx-gMXG66lifXNdNkIVTbzB-XZSD1WKah6I) for article 'Zoom: Third-Party Apps/Bots Join Meetings Without an Invite'
# Found article ID '6494' in tracking dict. Using Google Doc ID: 1HrRFUlqu_9R4U4cUra5HJ27q-TO6KzAE-YChJCfyQe8
# Successfully updated Google Doc (ID: 1HrRFUlqu_9R4U4cUra5HJ27q-TO6KzAE-YChJCfyQe8) for article 'Zoom: Transfer Meeting Ownership to a New Host'
# Found article ID '9594' in tracking dict. Using Google Doc ID: 19lQkUip71lcLa_t0hkUSZA2FxD5k6dw7D51oiMST0gs
# Successfully updated Google Doc (ID: 19lQkUip71lcLa_t0hkUSZA2FxD5k6dw7D51oiMST0gs) for article 'Zoom: Turn on Q&A Feature for Meetings and Webinars'
# Found article ID '746' in tracking dict. Using Google Doc ID: 1j0aVhosvwHx2YWJojyaZdu54bgpembQRaTvftjuLmB0
# Successfully updated Google Doc (ID: 1j0aVhosvwHx2YWJojyaZdu54bgpembQRaTvftjuLmB0) for article 'Zoom: Update Your Name'
# Found article ID '3836' in tracking dict. Using Google Doc ID: 1hsg2LT_130jJr9VZqSglilpcp5FRo6GAiOZ_9xBVH_U
# Successfully updated Google Doc (ID: 1hsg2LT_130jJr9VZqSglilpcp5FRo6GAiOZ_9xBVH_U) for article 'Zoom: Update the App on a Computer or Mobile Device'
# Found article ID '11479' in tracking dict. Using Google Doc ID: 1zwriwG2QN575IbnHQEdFX3XCwWk0vHGgYBRXKB3St5Y
# Successfully updated Google Doc (ID: 1zwriwG2QN575IbnHQEdFX3XCwWk0vHGgYBRXKB3St5Y) for article 'Zoom: Use the Annotation Tools'
# Found article ID '1323' in tracking dict. Using Google Doc ID: 1hKsdXOdOmF5CBw6Ex5NPOg1pxrGxbGc6CiCCtgche0c
# Successfully updated Google Doc (ID: 1hKsdXOdOmF5CBw6Ex5NPOg1pxrGxbGc6CiCCtgche0c) for article 'Zoom: Virtual Backgrounds'
# Found article ID '4561' in tracking dict. Using Google Doc ID: 1II2Qv2dZaP7pABpmey8PhOmJn691wPLRsVlVPMO4R7o
# Successfully updated Google Doc (ID: 1II2Qv2dZaP7pABpmey8PhOmJn691wPLRsVlVPMO4R7o) for article 'Zoom: Zoom for Google Workspace Add-on Meetings Not Syncing ("Google Calendar Meeting (not synced)")'
# Found article ID '808' in tracking dict. Using Google Doc ID: 1bojgwBUMQMUAtmmXH7U4eSLLNS5O2u2g-E9Q_TEPm3o
# Successfully updated Google Doc (ID: 1bojgwBUMQMUAtmmXH7U4eSLLNS5O2u2g-E9Q_TEPm3o) for article 'careers.umich.edu Password - Only 3 Characters Displayed'
# Found article ID '6800' in tracking dict. Using Google Doc ID: 1421rbfEjeoPYcVg5yATotuZStIGRTSUqruSS0WgIO7g
# Successfully updated Google Doc (ID: 1421rbfEjeoPYcVg5yATotuZStIGRTSUqruSS0WgIO7g) for article 'e-Signature: User is Banned from SignNow or Account Deactivated'
# Found article ID '1269' in tracking dict. Using Google Doc ID: 1-dn_EFwjEcAjwlXGQn2tT33wo-3ybEWNeEqmP4AXSXk
# Successfully updated Google Doc (ID: 1-dn_EFwjEcAjwlXGQn2tT33wo-3ybEWNeEqmP4AXSXk) for article 'eProcurement (ePro) Requisition (req) - How Do I Setup an Alternate Approver?'
# Found article ID '9422' in tracking dict. Using Google Doc ID: 1_WeDeqkVSJhsCSY9DBQMFb48eyelyJ8L8Aee6zu67hc
# Successfully updated Google Doc (ID: 1_WeDeqkVSJhsCSY9DBQMFb48eyelyJ8L8Aee6zu67hc) for article 'eProcurement: Change Default Ship To and Shortcode'
# Found article ID '1186' in tracking dict. Using Google Doc ID: 1KWKC9bZaB4K6HxHdirgKDmf32z5w7LnYcqxcmtNWshY
# Successfully updated Google Doc (ID: 1KWKC9bZaB4K6HxHdirgKDmf32z5w7LnYcqxcmtNWshY) for article 'eRAM: New User Access to eResearch Animal Management'
# Found article ID '3373' in tracking dict. Using Google Doc ID: 1jJ3bgLuz9Ma40hwEI5YtW5I3iqTOp8VveDFmWAhGTK8
# Successfully updated Google Doc (ID: 1jJ3bgLuz9Ma40hwEI5YtW5I3iqTOp8VveDFmWAhGTK8) for article 'eRPM: "An error occurred in the "getRequests" function. See the wom log for more detail." in eResearch Proposal Management'
# Found article ID '4269' in tracking dict. Using Google Doc ID: 1H5PMPK-eZCJMKRBp3pQFqaKmQumyas7gUeaqh9dl9gE
# Successfully updated Google Doc (ID: 1H5PMPK-eZCJMKRBp3pQFqaKmQumyas7gUeaqh9dl9gE) for article 'eRPM: Access Required for PAF Query Tab in eResearch Proposal Management'
# Found article ID '413' in tracking dict. Using Google Doc ID: 17kfekG_NWxVgLTkBhfhQEm1s2-JRAICMG8RZTJU62JA
# Successfully updated Google Doc (ID: 17kfekG_NWxVgLTkBhfhQEm1s2-JRAICMG8RZTJU62JA) for article 'eRPM: Cancel a PAF in eResearch Proposal Management'
# Found article ID '10080' in tracking dict. Using Google Doc ID: 1Ry_MuMl99U1yfprqx4ZG85arTkGty5vtyT8tRwtJxCw
# Successfully updated Google Doc (ID: 1Ry_MuMl99U1yfprqx4ZG85arTkGty5vtyT8tRwtJxCw) for article 'eRPM: Clone a PAF in eResearch Proposal Management'
# Found article ID '411' in tracking dict. Using Google Doc ID: 1xrG_wMlC4AgkyRdrjQ_Susx6br4O8we50tGTdR0zIiY
# Successfully updated Google Doc (ID: 1xrG_wMlC4AgkyRdrjQ_Susx6br4O8we50tGTdR0zIiY) for article 'eRPM: Grants.gov Link Missing on the PAF Workspace in eResearch Proposal Management'
# Found article ID '7316' in tracking dict. Using Google Doc ID: 1rGsSrsrjGn0GDwGEs7uixD9hgoqtDcH8ArXonYyJ3qs
# Successfully updated Google Doc (ID: 1rGsSrsrjGn0GDwGEs7uixD9hgoqtDcH8ArXonYyJ3qs) for article 'eRPM: Lost Access to View Records in eResearch Proposal Management'
# Found article ID '415' in tracking dict. Using Google Doc ID: 18OTVwdsV53CRlDw6bmJcxJY6XcdJlVOxLnQguIdokrg
# Successfully updated Google Doc (ID: 18OTVwdsV53CRlDw6bmJcxJY6XcdJlVOxLnQguIdokrg) for article 'eRPM: Manage Department Information & Review Access in eResearch Proposal Management'
# Found article ID '1178' in tracking dict. Using Google Doc ID: 1p5MXIslcgFgIRvUQ4J36XzJ13h6CUyKWD1t1UCNv0v4
# Successfully updated Google Doc (ID: 1p5MXIslcgFgIRvUQ4J36XzJ13h6CUyKWD1t1UCNv0v4) for article 'eRPM: Request to Reset FOA'
# Found article ID '7196' in tracking dict. Using Google Doc ID: 1gKKVy7AuGTcUet6G5u-LbcrAY4xPg2QErzMRssTSiWs
# Successfully updated Google Doc (ID: 1gKKVy7AuGTcUet6G5u-LbcrAY4xPg2QErzMRssTSiWs) for article 'eRPM: Restore Cancelled PAF in eResearch Proposal Management'
# Found article ID '416' in tracking dict. Using Google Doc ID: 1FXfALcp5NH28LY58HoSvwMuc6uU9HGvwJwsACZod5Qo
# Successfully updated Google Doc (ID: 1FXfALcp5NH28LY58HoSvwMuc6uU9HGvwJwsACZod5Qo) for article 'eRPM: Restore Missing "Copy PAF Info to Grants.gov Forms" Activity in eResearch Proposal Management'
# Found article ID '6396' in tracking dict. Using Google Doc ID: 11jWN6wbAnmldCx3V7SqyZ0tHVtmokFjaKmsbMnk5jVY
# Successfully updated Google Doc (ID: 11jWN6wbAnmldCx3V7SqyZ0tHVtmokFjaKmsbMnk5jVY) for article 'eRRM: Accept Role Activity Not Available Until Application Type is Selected in eResearch Regulatory Management'
# Found article ID '3315' in tracking dict. Using Google Doc ID: 1mWxXRJZQsqy30kvKwxeue0idXNHamBNASpY0nwRmwFk
# Successfully updated Google Doc (ID: 1mWxXRJZQsqy30kvKwxeue0idXNHamBNASpY0nwRmwFk) for article 'eRRM: Accept Role on Study Team in eResearch Regulatory Management'
# Found article ID '1175' in tracking dict. Using Google Doc ID: 1GYGGDYFZR2VN5BjRYYDtT0ujAq28Vsmas003t9Pv9qc
# Successfully updated Google Doc (ID: 1GYGGDYFZR2VN5BjRYYDtT0ujAq28Vsmas003t9Pv9qc) for article 'eRRM: Appointment Information Incorrect in eResearch Regulatory Management'
# Found article ID '8418' in tracking dict. Using Google Doc ID: 1EIIyzg7r2hSh0GlULHZ_tpzDh30Rkxxx7MzhkxJOGRI
# Successfully updated Google Doc (ID: 1EIIyzg7r2hSh0GlULHZ_tpzDh30Rkxxx7MzhkxJOGRI) for article 'eRRM: Create an Account in eResearch Regulatory Management'
# Found article ID '1172' in tracking dict. Using Google Doc ID: 1NyU5KbGyNadWfyniRJ8MMWXDFE8CimGdBPjI-LsRACs
# Successfully updated Google Doc (ID: 1NyU5KbGyNadWfyniRJ8MMWXDFE8CimGdBPjI-LsRACs) for article 'eRRM: How Student Affiliation Affects Appointment Selection in eResearch Regulatory Management'
# Found article ID '11293' in tracking dict. Using Google Doc ID: 1yzVn-zIBkA1Q1LDunUB5wWU5BNjFY9NXaPTBJ400iw0
# Successfully updated Google Doc (ID: 1yzVn-zIBkA1Q1LDunUB5wWU5BNjFY9NXaPTBJ400iw0) for article 'eRRM: New Friend Account Users Accessing eResearch Regulatory Management'
# Found article ID '1168' in tracking dict. Using Google Doc ID: 1LaMTjI8QxBZffeDG6GdJBlEwHSqwkZEABo9QXRfOo_A
# Successfully updated Google Doc (ID: 1LaMTjI8QxBZffeDG6GdJBlEwHSqwkZEABo9QXRfOo_A) for article 'eRRM: No Appointment Populated for Study Team Member in eResearch Regulatory Management'
# Found article ID '3363' in tracking dict. Using Google Doc ID: 115H4h9eIOq4LKq1_3-zKLeoLn-zuXrOw2eUpWBC9YA8
# Successfully updated Google Doc (ID: 115H4h9eIOq4LKq1_3-zKLeoLn-zuXrOw2eUpWBC9YA8) for article 'eRRM: PEERRS Certification Status in eResearch Regulatory Management'
# Found article ID '3485' in tracking dict. Using Google Doc ID: 1ZnoiONsdSMyzbyP9_gzzKvhLz1bl1ZdV9UNmtyT46Yk
# Successfully updated Google Doc (ID: 1ZnoiONsdSMyzbyP9_gzzKvhLz1bl1ZdV9UNmtyT46Yk) for article 'eRRM: When a Person Already has an Account But Wants/Needs a Different One in eResearch Regulatory Management'
# Found article ID '418' in tracking dict. Using Google Doc ID: 1vGJ7kukjVFt-Kgfo-lWGMrH60cdrN-GB5AGgtQG0Gw8
# Successfully updated Google Doc (ID: 1vGJ7kukjVFt-Kgfo-lWGMrH60cdrN-GB5AGgtQG0Gw8) for article 'eRRM: Withdraw a HUM, AME, CR, ADV, REP, IBCA, SITE application in eResearch Regulatory Management'
# Found article ID '1174' in tracking dict. Using Google Doc ID: 11RHMB2ycUd2K9Aepld1dF9a6beyh8zYfC_NAcUAenb0
# Successfully updated Google Doc (ID: 11RHMB2ycUd2K9Aepld1dF9a6beyh8zYfC_NAcUAenb0) for article 'eResearch: Accessing eResearch as a Non-UM User'
# Found article ID '324' in tracking dict. Using Google Doc ID: 1T3NtqBZEiD8zL0cw3vqUbKaY7PH4hMcRGtHcApY_VIU
# Successfully updated Google Doc (ID: 1T3NtqBZEiD8zL0cw3vqUbKaY7PH4hMcRGtHcApY_VIU) for article 'eSignature:  SignNow New Account Request'
# Found article ID '6823' in tracking dict. Using Google Doc ID: 1KBxtrov-WgKZzKFapFnBiU_Id4keTf77o5k-18imsB4
# Successfully updated Google Doc (ID: 1KBxtrov-WgKZzKFapFnBiU_Id4keTf77o5k-18imsB4) for article 'eSignature:  Two Versions of SignNow - Standard and FDA-Compliant'
# Found article ID '6634' in tracking dict. Using Google Doc ID: 1RunCYEY4B16aeL_zujMdfGfIOzxX4q08WVzeopE5XZU
# Successfully updated Google Doc (ID: 1RunCYEY4B16aeL_zujMdfGfIOzxX4q08WVzeopE5XZU) for article 'eSignature:  Using SignNow for FDA-regulated Documents'
# Found article ID '1213' in tracking dict. Using Google Doc ID: 1RUFZUdPL-jLXocqpVr_5wddQEqKu6nwA8QjysqP3qBs
# Successfully updated Google Doc (ID: 1RUFZUdPL-jLXocqpVr_5wddQEqKu6nwA8QjysqP3qBs) for article 'eSignature: Assistance with SignNow (Sign Now)'
# Found article ID '3500' in tracking dict. Using Google Doc ID: 1DaipUTyxWymo8lx4wjGShWlPXj59tXNEzWhooQEUbyo
# Successfully updated Google Doc (ID: 1DaipUTyxWymo8lx4wjGShWlPXj59tXNEzWhooQEUbyo) for article 'eSignature: Email Accounts Other than @umich.edu when Requesting a SignNow Account'
# Found article ID '7575' in tracking dict. Using Google Doc ID: 1w4QBV813h9pwyYjF_nHxqlDDE0U3TOYdMN3nZDJGabg
# Successfully updated Google Doc (ID: 1w4QBV813h9pwyYjF_nHxqlDDE0U3TOYdMN3nZDJGabg) for article 'eSignature: Flattening PDF for Upload to a Third Party'
# Found article ID '3993' in tracking dict. Using Google Doc ID: 1mJClB_T1z9XRznUBBWaZwqt1oZuVBbugkPc5Ch9xWic
# Successfully updated Google Doc (ID: 1mJClB_T1z9XRznUBBWaZwqt1oZuVBbugkPc5Ch9xWic) for article 'eSignature: Issues When Logging into SignNow'
# Found article ID '4190' in tracking dict. Using Google Doc ID: 1J3syH680AzBMOWvXmTqNV4tJVjPf9Veu4riAmNlfojs
# Successfully updated Google Doc (ID: 1J3syH680AzBMOWvXmTqNV4tJVjPf9Veu4riAmNlfojs) for article 'eSignature: Unable to Upload Documents in SignNow / Subscription Expired Message'
# Found article ID '3362' in tracking dict. Using Google Doc ID: 1nES6rV7iMbTtVIMLXXvFYVSQIczGqeA7MBbce-vC4A4
# Successfully updated Google Doc (ID: 1nES6rV7iMbTtVIMLXXvFYVSQIczGqeA7MBbce-vC4A4) for article 'eSignature: Unable to join SignNow Team'
# Found article ID '7088' in tracking dict. Using Google Doc ID: 1K2bSR9Ro09M6XlXf8iaBuxUOOWHvSIkrqzYmAlZUOiY
# Successfully updated Google Doc (ID: 1K2bSR9Ro09M6XlXf8iaBuxUOOWHvSIkrqzYmAlZUOiY) for article 'eSignature: Upgrade an Already Created SignNow Account to FDA-Compliant Version'
# Found article ID '6982' in tracking dict. Using Google Doc ID: 1z-GD7XPIq_jlqYw9pzBDYRnOideP5rVmewOsjWO04JE
# Successfully updated Google Doc (ID: 1z-GD7XPIq_jlqYw9pzBDYRnOideP5rVmewOsjWO04JE) for article 'iPhone, iPad Has Blank Page or Will Not Connect to MSetup WiFi Network'
# Found article ID '6929' in tracking dict. Using Google Doc ID: 1sepmv4yt6k2jUKP9l3vbCEdwcC0wMPRpuwxIx4cB0ro
# Successfully updated Google Doc (ID: 1sepmv4yt6k2jUKP9l3vbCEdwcC0wMPRpuwxIx4cB0ro) for article 'mFile Retirement Project'
# Found article ID '7577' in tracking dict. Using Google Doc ID: 1zHPNQlykXaA8QtWxUesh_XsBey4lCsLjGPd2qgPvTgI
# Successfully updated Google Doc (ID: 1zHPNQlykXaA8QtWxUesh_XsBey4lCsLjGPd2qgPvTgI) for article 'phpMyAdmin Tool Support'
# Found article ID '6440' in tracking dict. Using Google Doc ID: 1QvduIlJ1H_4jzqzn-DzMXVA8sEGlgVWgkdmSQnw6u6c
# Successfully updated Google Doc (ID: 1QvduIlJ1H_4jzqzn-DzMXVA8sEGlgVWgkdmSQnw6u6c) for article 'umichWORKS Slack Workspace Information'
# Found article ID '10665' in tracking dict. Using Google Doc ID: 1_dlhQ2ldvxQ1ToJYxW29gqIxGcAJUN_LVhtgrXgAFpI
# Successfully updated Google Doc (ID: 1_dlhQ2ldvxQ1ToJYxW29gqIxGcAJUN_LVhtgrXgAFpI) for article '“Add Deskset” Option in Service Request System (SRS)'
